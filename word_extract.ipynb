# %%
import numpy as np
import pandas as pd

from tqdm import tqdm

# %% [markdown]
# # 코로나 백신 부작용 증상 목록 생성

# %%
SYMPTOMS_df = pd.DataFrame()
VAX_df = pd.DataFrame()

startYear = 2020 # 통합할 데이터의 시작연도
numOfFiles = 2 # 파일의 갯수
for i in tqdm(range(0, numOfFiles, 1)):
    symptoms_df = pd.read_csv('./dataset/AllVAERSDataCSVS/' + str(startYear+i) + 'VAERSSYMPTOMS.csv', encoding='latin')
    vax_df = pd.read_csv('./dataset/AllVAERSDataCSVS/' + str(startYear+i) + 'VAERSVAX.csv', encoding='latin')
    
    SYMPTOMS_df = pd.concat([SYMPTOMS_df, symptoms_df])
    VAX_df = pd.concat([VAX_df, vax_df])
    
    del symptoms_df
    del vax_df
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:01<00:00,  1.41it/s]

# %%
# 필요한 피처만 남기고 제거
SYMPTOMS_df = SYMPTOMS_df[['VAERS_ID', 'SYMPTOM1', 'SYMPTOM2', 'SYMPTOM3', 'SYMPTOM4', 'SYMPTOM5']]
VAX_df = VAX_df[['VAERS_ID', 'VAX_TYPE']]

# %%
# VAERS_ID 기준으로 inner join
VAERS_df = pd.merge(SYMPTOMS_df, VAX_df, how='inner', on='VAERS_ID')
VAERS_df.head()
# Out:
#    VAERS_ID           SYMPTOM1                SYMPTOM2             SYMPTOM3  \
# 0    855017         Arthralgia                  Chills  Injection site pain
# 1    855018             Chills                 Fatigue         Hypertension
# 2    855018  Muscular weakness       Pain in extremity              Pyrexia
# 3    855019               Pain                Pruritus                 Rash
# 4    855020             Chills  Influenza like illness              Myalgia
#
#             SYMPTOM4                          SYMPTOM5 VAX_TYPE
# 0            Pyrexia                               NaN   VARZOS
# 1      Hypoaesthesia  Injected limb mobility decreased      UNK
# 2             Tremor                           Vertigo      UNK
# 3                NaN                               NaN   VARZOS
# 4  Pain in extremity                           Pyrexia   VARZOS

# %%
# COVID19인 행만 추출
VAERS_df = VAERS_df[VAERS_df['VAX_TYPE'] == 'COVID19']
VAERS_df.head()
# Out:
#        VAERS_ID       SYMPTOM1                      SYMPTOM2       SYMPTOM3  \
# 56963    902418  Hypoaesthesia  Injection site hypoaesthesia            NaN
# 56983    902440       Headache                           NaN            NaN
# 56990    902446       Erythema                   Feeling hot       Flushing
# 57013    902464      Dizziness      Electrocardiogram normal  Hyperhidrosis
# 57014    902465      Dysgeusia                 Oral pruritus   Paraesthesia
#
#                      SYMPTOM4    SYMPTOM5 VAX_TYPE
# 56963                     NaN         NaN  COVID19
# 56983                     NaN         NaN  COVID19
# 56990                     NaN         NaN  COVID19
# 57013  Laboratory test normal  Presyncope  COVID19
# 57014       Paraesthesia oral    Parosmia  COVID19

# %%
covid_symptom_2list = VAERS_df[['SYMPTOM1', 'SYMPTOM2', 'SYMPTOM3', 'SYMPTOM4', 'SYMPTOM5']].values

# %%
# 2차원 리스트를 1차원으로
covid_symptom_list = [element for array in covid_symptom_2list for element in array]

# %%
import collections
covid_rank_list = collections.Counter(covid_symptom_list).most_common()[1:]
covid_rank_list
# Out:
# [('Headache', 104383),
#  ('Pyrexia', 86837),
#  ('Fatigue', 85767),
#  ('Chills', 77515),
#  ('Pain', 74016),
#  ('Dizziness', 60425),
#  ('Nausea', 59776),
#  ('Pain in extremity', 55030),
#  ('Myalgia', 35636),
#  ('Injection site pain', 35171),
#  ('Arthralgia', 33633),
#  ('Rash', 30556),
#  ('Dyspnoea', 30176),
#  ('Pruritus', 28354),
#  ('Injection site erythema', 25446),
#  ('Vomiting', 23085),
#  ('Asthenia', 22481),
#  ('Injection site swelling', 20568),
#  ('Erythema', 19500),
#  ('Hyperhidrosis', 18957),
#  ('Paraesthesia', 18938),
#  ('Diarrhoea', 18938),
#  ('COVID-19', 18145),
#  ('Injection site pruritus', 18096),
#  ('Feeling abnormal', 17385),
#  ('Hypoaesthesia', 17329),
#  ('Urticaria', 17063),
#  ('Malaise', 16196),
#  ('Lymphadenopathy', 16029),
#  ('Chest pain', 15415),
#  ('Cough', 14779),
#  ('Peripheral swelling', 14090),
#  ('SARS-CoV-2 test positive', 13598),
#  ('Injection site warmth', 13078),
#  ('Syncope', 12167),
#  ('Chest discomfort', 11596),
#  ('Vaccination site pain', 11406),
#  ('Tremor', 11090),
#  ('Blood test', 11070),
#  ('Heart rate increased', 10865),
#  ('Palpitations', 10760),
#  ('Tinnitus', 10735),
#  ('Back pain', 10728),
#  ('SARS-CoV-2 test', 10586),
#  ('Injection site rash', 10216),
#  ('Feeling hot', 10065),
#  ('Decreased appetite', 9339),
#  ('Swelling', 9027),
#  ('Condition aggravated', 8978),
#  ('Loss of consciousness', 8888),
#  ('Rash erythematous', 8859),
#  ('Oropharyngeal pain', 8808),
#  ('Neck pain', 8662),
#  ('Electrocardiogram', 8513),
#  ('Flushing', 7869),
#  ('Product administered to patient of inappropriate age', 7838),
#  ('Influenza like illness', 7738),
#  ('Skin warm', 7622),
#  ('Rash pruritic', 7556),
#  ('Body temperature', 7169),
#  ('Mobility decreased', 7051),
#  ('SARS-CoV-2 test negative', 7014),
#  ('Migraine', 6980),
#  ('Sleep disorder', 6748),
#  ('Anxiety', 6570),
#  ('Body temperature increased', 6342),
#  ('Product storage error', 6338),
#  ('No adverse event', 6284),
#  ('Muscle spasms', 6245),
#  ('Vertigo', 6224),
#  ('Abdominal pain upper', 6126),
#  ('Insomnia', 6035),
#  ('Death', 6007),
#  ('Swelling face', 5980),
#  ('Computerised tomogram', 5966),
#  ('Paraesthesia oral', 5923),
#  ('Vaccination site erythema', 5837),
#  ('Feeling cold', 5796),
#  ('Throat tightness', 5719),
#  ('Herpes zoster', 5687),
#  ('Inappropriate schedule of product administration', 5633),
#  ('Lethargy', 5603),
#  ('Vision blurred', 5550),
#  ('Fall', 5544),
#  ('Muscular weakness', 5514),
#  ('Gait disturbance', 5510),
#  ('Abdominal pain', 5458),
#  ('Burning sensation', 5421),
#  ('Musculoskeletal stiffness', 5416),
#  ('Blood pressure increased', 5238),
#  ('Somnolence', 5137),
#  ('Hypertension', 5098),
#  ('Laboratory test', 4985),
#  ('Throat irritation', 4981),
#  ('Injection site induration', 4953),
#  ('Rhinorrhoea', 4887),
#  ('Pallor', 4868),
#  ('Full blood count', 4819),
#  ('Impaired work ability', 4806),
#  ('Tachycardia', 4780),
#  ('Abdominal discomfort', 4644),
#  ('Immediate post-injection reaction', 4640),
#  ('Vaccination site swelling', 4636),
#  ('Chest X-ray', 4516),
#  ('Lip swelling', 4355),
#  ('Confusional state', 4308),
#  ('Metabolic function test', 4248),
#  ('Unevaluable event', 4245),
#  ('Axillary pain', 4119),
#  ('Hypoaesthesia oral', 4095),
#  ('Injection site reaction', 4092),
#  ('Dysphagia', 4090),
#  ('Interchange of vaccine products', 4015),
#  ('Electrocardiogram normal', 3932),
#  ('Nasal congestion', 3926),
#  ('Tenderness', 3911),
#  ('Limb discomfort', 3903),
#  ('Swollen tongue', 3882),
#  ('Magnetic resonance imaging', 3868),
#  ('Vaccination site pruritus', 3807),
#  ('Dysgeusia', 3751),
#  ('Seizure', 3687),
#  ('Pharyngeal swelling', 3682),
#  ('Rash macular', 3522),
#  ('Loss of personal independence in daily activities', 3522),
#  ('Unresponsive to stimuli', 3517),
#  ('Cold sweat', 3516),
#  ('Lymph node pain', 3515),
#  ('Ageusia', 3422),
#  ('Discomfort', 3240),
#  ('Hypotension', 3206),
#  ('Hot flush', 3187),
#  ('Contusion', 3144),
#  ('Echocardiogram', 3088),
#  ('Visual impairment', 3077),
#  ('Blood test normal', 3077),
#  ('Illness', 3068),
#  ('Expired product administered', 3058),
#  ('Blood pressure measurement', 3055),
#  ('Vaccination site warmth', 3051),
#  ('Balance disorder', 3049),
#  ('Hypersensitivity', 3027),
#  ('Ear pain', 2990),
#  ('Thrombosis', 2983),
#  ('Ultrasound scan', 2929),
#  ("Bell's palsy", 2905),
#  ('Heavy menstrual bleeding', 2824),
#  ('X-ray', 2808),
#  ('Rash papular', 2753),
#  ('Urine analysis', 2736),
#  ('Exposure during pregnancy', 2686),
#  ('Joint swelling', 2683),
#  ('Incorrect dose administered', 2680),
#  ('Nasopharyngitis', 2677),
#  ('Presyncope', 2673),
#  ('Vaccination complication', 2665),
#  ('Anosmia', 2626),
#  ('Pulmonary embolism', 2613),
#  ('Heart rate', 2555),
#  ('Injection site mass', 2497),
#  ('Cerebrovascular accident', 2477),
#  ('Eye pain', 2466),
#  ('Eye swelling', 2446),
#  ('Vaccination site rash', 2413),
#  ('Head discomfort', 2395),
#  ('Inflammation', 2336),
#  ('Wheezing', 2326),
#  ('Chest X-ray normal', 2320),
#  ('Full blood count normal', 2311),
#  ('Night sweats', 2283),
#  ('Drug ineffective', 2207),
#  ('Respiratory tract congestion', 2183),
#  ('Extra dose administered', 2168),
#  ('Facial paralysis', 2166),
#  ('Menstruation irregular', 2125),
#  ('Pneumonia', 2067),
#  ('Underdose', 2048),
#  ('Dehydration', 2031),
#  ('Hypersomnia', 2005),
#  ('Ear discomfort', 2004),
#  ('Dysstasia', 1998),
#  ('Poor quality product administered', 1956),
#  ('Deep vein thrombosis', 1929),
#  ('Blister', 1926),
#  ('Disorientation', 1902),
#  ('Nervousness', 1891),
#  ('Skin discolouration', 1885),
#  ('Epistaxis', 1884),
#  ('Dry mouth', 1881),
#  ('Injection site bruising', 1855),
#  ('Computerised tomogram head', 1838),
#  ('Bone pain', 1826),
#  ('Neuralgia', 1792),
#  ('Electrocardiogram abnormal', 1787),
#  ('Product dose omission issue', 1775),
#  ('Taste disorder', 1773),
#  ('Troponin increased', 1764),
#  ('Muscle tightness', 1763),
#  ('Induration', 1761),
#  ('Atrial fibrillation', 1757),
#  ('Disturbance in attention', 1755),
#  ('Muscle twitching', 1719),
#  ('Menstrual disorder', 1704),
#  ('Pain in jaw', 1687),
#  ('Myocarditis', 1670),
#  ('Anaphylactic reaction', 1660),
#  ('Computerised tomogram normal', 1625),
#  ('Blood glucose increased', 1618),
#  ('Gait inability', 1613),
#  ('Intensive care', 1591),
#  ('Blood glucose normal', 1574),
#  ('Head injury', 1564),
#  ('Photophobia', 1503),
#  ('Product preparation issue', 1493),
#  ('Dysphonia', 1482),
#  ('Laboratory test normal', 1464),
#  ('Chest X-ray abnormal', 1450),
#  ('Peripheral coldness', 1449),
#  ('Pain of skin', 1441),
#  ('Troponin', 1426),
#  ('White blood cell count increased', 1416),
#  ('Vaccine positive rechallenge', 1413),
#  ('C-reactive protein increased', 1400),
#  ('Vital signs measurement', 1399),
#  ('Aphasia', 1391),
#  ('Anticoagulant therapy', 1364),
#  ('Platelet count decreased', 1353),
#  ('Retching', 1350),
#  ('Injection site urticaria', 1338),
#  ('Sneezing', 1325),
#  ('Dyspepsia', 1324),
#  ('Movement disorder', 1310),
#  ('Cellulitis', 1307),
#  ('Breast pain', 1306),
#  ('Dysarthria', 1295),
#  ('Injected limb mobility decreased', 1292),
#  ('Echocardiogram normal', 1288),
#  ('Oropharyngeal discomfort', 1277),
#  ('Ultrasound Doppler', 1275),
#  ('Magnetic resonance imaging head', 1271),
#  ('Abdominal distension', 1269),
#  ('Skin burning sensation', 1262),
#  ('Heart rate irregular', 1259),
#  ('Joint range of motion decreased', 1257),
#  ('Speech disorder', 1250),
#  ('COVID-19 pneumonia', 1232),
#  ('Memory impairment', 1219),
#  ('Oedema peripheral', 1216),
#  ('Oxygen saturation decreased', 1216),
#  ('Weight decreased', 1213),
#  ('Dysmenorrhoea', 1205),
#  ('Deafness', 1204),
#  ('Urinary tract infection', 1177),
#  ('Computerised tomogram thorax', 1177),
#  ('Asthma', 1175),
#  ('Thirst', 1173),
#  ('Acute kidney injury', 1173),
#  ('Blood pressure decreased', 1168),
#  ('Hypoacusis', 1163),
#  ('Ocular hyperaemia', 1155),
#  ('Vaccination site induration', 1154),
#  ('Eye pruritus', 1145),
#  ('SARS-CoV-2 antibody test', 1136),
#  ('Pericarditis', 1115),
#  ('Arthritis', 1111),
#  ('Facial pain', 1105),
#  ('Myocardial infarction', 1099),
#  ('Feeling of body temperature change', 1094),
#  ('Fibrin D dimer', 1089),
#  ('Vaginal haemorrhage', 1072),
#  ('Computerised tomogram abnormal', 1069),
#  ('Nodule', 1067),
#  ('Oral herpes', 1060),
#  ('Blood glucose', 1054),
#  ('Hypoxia', 1050),
#  ('Exposure to SARS-CoV-2', 1047),
#  ('Vaccination site reaction', 1043),
#  ('Musculoskeletal discomfort', 1037),
#  ('Parosmia', 1034),
#  ('Joint stiffness', 1034),
#  ('Fibrin D dimer increased', 1032),
#  ('Sensitive skin', 1022),
#  ('Lacrimation increased', 1013),
#  ('Influenza', 997),
#  ('Syringe issue', 996),
#  ('Angiogram', 990),
#  ('Computerised tomogram thorax abnormal', 990),
#  ('Amnesia', 982),
#  ('Product temperature excursion issue', 978),
#  ('Injection site nodule', 975),
#  ('Panic attack', 972),
#  ('Dyskinesia', 970),
#  ('Sensation of foreign body', 963),
#  ('Vaccination site mass', 959),
#  ('Productive cough', 951),
#  ('Eye irritation', 941),
#  ('Blood thyroid stimulating hormone', 939),
#  ('Haemoglobin decreased', 932),
#  ('Oxygen saturation', 909),
#  ('Feeding disorder', 908),
#  ('Musculoskeletal chest pain', 905),
#  ('Magnetic resonance imaging normal', 897),
#  ('Injection site inflammation', 896),
#  ('Intermenstrual bleeding', 893),
#  ('Swelling of eyelid', 888),
#  ('Magnetic resonance imaging head abnormal', 884),
#  ('Heart rate decreased', 869),
#  ('Echocardiogram abnormal', 865),
#  ('Pharyngeal paraesthesia', 861),
#  ('Platelet count normal', 861),
#  ('Maternal exposure during pregnancy', 861),
#  ('Computerised tomogram head normal', 856),
#  ('Abortion spontaneous', 843),
#  ('Ultrasound Doppler abnormal', 836),
#  ('Acoustic stimulation tests', 835),
#  ('Neuropathy peripheral', 834),
#  ('Magnetic resonance imaging head normal', 832),
#  ('Constipation', 830),
#  ('Deafness unilateral', 826),
#  ('Blood test abnormal', 826),
#  ('Urine analysis normal', 824),
#  ('Restlessness', 822),
#  ('Blindness', 820),
#  ('Sensory disturbance', 817),
#  ('Vaccination failure', 813),
#  ('Cardiac arrest', 812),
#  ('Metabolic function test normal', 805),
#  ('Sinusitis', 802),
#  ('Skin exfoliation', 800),
#  ('Impaired driving ability', 788),
#  ('Eye movement disorder', 787),
#  ('Endotracheal intubation', 780),
#  ('Cardiac stress test', 776),
#  ('Diplopia', 773),
#  ('Mass', 772),
#  ('Depression', 765),
#  ('Dry throat', 764),
#  ('C-reactive protein', 762),
#  ('Hallucination', 762),
#  ('Sinus congestion', 761),
#  ('Influenza virus test negative', 760),
#  ('Red blood cell sedimentation rate increased', 759),
#  ('Cardiac monitoring', 758),
#  ('Toothache', 756),
#  ('Dyspnoea exertional', 749),
#  ('Off label use', 746),
#  ('Mental status changes', 742),
#  ('Differential white blood cell count', 738),
#  ('Alopecia', 737),
#  ('Menstruation delayed', 731),
#  ('Troponin normal', 729),
#  ('Acute myocardial infarction', 729),
#  ('Incorrect route of product administration', 723),
#  ('Mouth swelling', 719),
#  ('Computerised tomogram abdomen', 717),
#  ('Acute respiratory failure', 713),
#  ('Dry skin', 710),
#  ('Cardiac flutter', 699),
#  ('Angioedema', 695),
#  ('Haemorrhage', 693),
#  ('Blood creatinine increased', 686),
#  ('Hypokinesia', 683),
#  ('Flatulence', 680),
#  ('Hemiparesis', 680),
#  ('Wrong product administered', 678),
#  ('Ocular discomfort', 677),
#  ('Paranasal sinus discomfort', 675),
#  ('Arrhythmia', 665),
#  ('White blood cell count normal', 658),
#  ('Computerised tomogram head abnormal', 658),
#  ('Ultrasound scan abnormal', 647),
#  ('Scan with contrast', 644),
#  ('Petechiae', 643),
#  ('Thrombocytopenia', 642),
#  ('Adverse reaction', 639),
#  ('Suspected COVID-19', 635),
#  ('Crying', 633),
#  ('Hyperventilation', 631),
#  ('Haemoglobin normal', 630),
#  ('Urinary incontinence', 629),
#  ('Red blood cell sedimentation rate normal', 627),
#  ('Periorbital swelling', 626),
#  ('Stomatitis', 621),
#  ('Infection', 619),
#  ('Guillain-Barre syndrome', 619),
#  ('Sluggishness', 618),
#  ('Pregnancy test', 617),
#  ('Sepsis', 617),
#  ('Oral discomfort', 612),
#  ('Investigation', 605),
#  ('Skin reaction', 602),
#  ('Lumbar puncture', 602),
#  ('Cognitive disorder', 601),
#  ('Adverse event', 594),
#  ('Injection site hypoaesthesia', 592),
#  ('Pollakiuria', 591),
#  ('Gastrooesophageal reflux disease', 591),
#  ('Lung opacity', 590),
#  ('Dizziness postural', 588),
#  ('Ultrasound scan normal', 587),
#  ('Magnetic resonance imaging abnormal', 586),
#  ('Alanine aminotransferase increased', 578),
#  ('Incorrect product formulation administered', 577),
#  ('Axillary mass', 573),
#  ('Aspartate aminotransferase increased', 572),
#  ('Irritability', 568),
#  ('Angina pectoris', 562),
#  ('Feeling jittery', 560),
#  ('Painful respiration', 558),
#  ('Mental impairment', 558),
#  ('Blood creatinine normal', 556),
#  ('Skin lesion', 552),
#  ('Blood urine present', 552),
#  ('Product administered at inappropriate site', 550),
#  ('Spinal pain', 550),
#  ('Bedridden', 550),
#  ('Angiogram pulmonary abnormal', 549),
#  ('Ventricular extrasystoles', 548),
#  ('Injection site discomfort', 548),
#  ('Blood potassium normal', 546),
#  ('Abdominal pain lower', 543),
#  ('Biopsy', 539),
#  ('Injection site paraesthesia', 538),
#  ('Streptococcus test negative', 538),
#  ('Oral pain', 538),
#  ('Resuscitation', 538),
#  ('Appendicitis', 534),
#  ('Immunoglobulin therapy', 534),
#  ('Transient ischaemic attack', 531),
#  ('Bradycardia', 531),
#  ('Skin swelling', 531),
#  ('C-reactive protein normal', 528),
#  ('Red blood cell sedimentation rate', 524),
#  ('Electrocardiogram ST segment elevation', 523),
#  ('Skin tightness', 518),
#  ('Rash vesicular', 515),
#  ('Neurological symptom', 515),
#  ('Renal pain', 509),
#  ('Hyperacusis', 508),
#  ('Electric shock sensation', 507),
#  ('Blood potassium decreased', 506),
#  ('Cardiac disorder', 503),
#  ('White blood cell count', 503),
#  ('Anaemia', 498),
#  ('Product preparation error', 497),
#  ('Tongue discomfort', 496),
#  ('Rheumatoid arthritis', 493),
#  ('Electrocardiogram ambulatory', 492),
#  ('Flank pain', 490),
#  ('Blood glucose decreased', 490),
#  ('Injection site discolouration', 486),
#  ('Haematocrit normal', 485),
#  ('White blood cell count decreased', 485),
#  ('Blood sodium normal', 483),
#  ('Antibody test', 481),
#  ('Hyperaesthesia', 479),
#  ('Pleural effusion', 479),
#  ('Platelet count', 479),
#  ('Breast swelling', 477),
#  ('Influenza B virus test', 476),
#  ('X-ray normal', 476),
#  ('Pulmonary thrombosis', 466),
#  ('Asymptomatic COVID-19', 465),
#  ('Product administration error', 464),
#  ('Tongue disorder', 463),
#  ('Electroencephalogram', 460),
#  ('Haematochezia', 459),
#  ('Dysuria', 459),
#  ('Glossodynia', 459),
#  ('Oral pruritus', 455),
#  ('Fear', 455),
#  ('Abnormal dreams', 454),
#  ('Poor quality sleep', 453),
#  ('Muscle fatigue', 450),
#  ('Tongue pruritus', 450),
#  ('Antinuclear antibody', 450),
#  ('Polymenorrhoea', 448),
#  ('Catheterisation cardiac', 446),
#  ('Laboratory test abnormal', 444),
#  ('Cyanosis', 444),
#  ('Influenza A virus test negative', 441),
#  ('Therapeutic response unexpected', 439),
#  ('Paralysis', 437),
#  ('Skin irritation', 436),
#  ('Gastrointestinal disorder', 434),
#  ('Hypopnoea', 430),
#  ('Injection site haemorrhage', 428),
#  ('Vaccination site bruising', 427),
#  ('Blepharospasm', 427),
#  ('Facial paresis', 427),
#  ('Vaccine breakthrough infection', 427),
#  ('Pharyngeal hypoaesthesia', 426),
#  ('Cardiac failure congestive', 426),
#  ('Sensory loss', 425),
#  ('Dry eye', 424),
#  ('Respiratory failure', 424),
#  ('Magnetic resonance imaging heart', 424),
#  ('Pericardial effusion', 422),
#  ('Oligomenorrhoea', 422),
#  ('Weight', 421),
#  ('Blood lactic acid', 420),
#  ('Chromaturia', 419),
#  ('Pulmonary pain', 416),
#  ('Vitreous floaters', 415),
#  ('Haematocrit decreased', 414),
#  ('Blood sodium decreased', 413),
#  ('SARS-CoV-2 antibody test negative', 411),
#  ('Oedema', 410),
#  ('Fibrin D dimer normal', 409),
#  ('Respiratory rate increased', 408),
#  ('Computerised tomogram abdomen abnormal', 408),
#  ('Physical examination', 408),
#  ('Blood chloride normal', 402),
#  ('Agitation', 402),
#  ('Ultrasound abdomen', 400),
#  ('Blood urea normal', 399),
#  ('Sinus tachycardia', 398),
#  ('Nightmare', 398),
#  ('Eczema', 398),
#  ('Tunnel vision', 397),
#  ('Seizure like phenomena', 395),
#  ('International normalised ratio', 394),
#  ('Depressed mood', 392),
#  ('Groin pain', 389),
#  ('Ear swelling', 388),
#  ('Eye disorder', 387),
#  ('Device connection issue', 385),
#  ('Respiratory distress', 385),
#  ('Body temperature decreased', 384),
#  ('Mechanical ventilation', 384),
#  ('Delirium', 382),
#  ('General physical health deterioration', 381),
#  ('Breast tenderness', 379),
#  ('Aphonia', 378),
#  ('Blood urea increased', 377),
#  ('Blood thyroid stimulating hormone normal', 373),
#  ('Immunisation', 371),
#  ('Ophthalmological examination', 370),
#  ('Prothrombin time', 368),
#  ('Brain natriuretic peptide increased', 367),
#  ('Grip strength decreased', 366),
#  ('Tachypnoea', 365),
#  ('Cerebral haemorrhage', 363),
#  ('Blood pressure abnormal', 362),
#  ('Upper-airway cough syndrome', 362),
#  ('Blood magnesium', 359),
#  ('Sinus pain', 359),
#  ('Computerised tomogram neck', 357),
#  ('Gout', 352),
#  ('Acoustic stimulation tests abnormal', 351),
#  ('Incomplete course of vaccination', 351),
#  ('Mammogram', 351),
#  ('Blood culture', 349),
#  ('Appendicectomy', 349),
#  ('Glycosylated haemoglobin', 348),
#  ('Bronchitis', 348),
#  ('Sinus disorder', 347),
#  ('Musculoskeletal pain', 346),
#  ('Injection site cellulitis', 345),
#  ('Postmenopausal haemorrhage', 345),
#  ('Heart rate abnormal', 343),
#  ('Respiratory viral panel', 342),
#  ('Red blood cell count decreased', 341),
#  ('Mean cell volume normal', 339),
#  ('Pulmonary oedema', 339),
#  ('Alanine aminotransferase normal', 338),
#  ('Blood pressure fluctuation', 338),
#  ('Limb injury', 336),
#  ('Throat clearing', 335),
#  ('Hyponatraemia', 334),
#  ('Amenorrhoea', 334),
#  ('Lung infiltration', 333),
#  ('Blood alkaline phosphatase normal', 332),
#  ('Pulmonary congestion', 332),
#  ('Walking aid user', 332),
#  ('Generalised tonic-clonic seizure', 331),
#  ('SARS-CoV-2 antibody test positive', 331),
#  ('Haemoptysis', 330),
#  ('Ejection fraction decreased', 329),
#  ('Magnetic resonance imaging neck', 329),
#  ('Thinking abnormal', 328),
#  ('Secretion discharge', 328),
#  ('Hypophagia', 328),
#  ('Biopsy skin', 327),
#  ('Respiration abnormal', 326),
#  ('Scan with contrast abnormal', 323),
#  ('Asthenopia', 322),
#  ('Blood creatine phosphokinase increased', 322),
#  ('Culture urine', 319),
#  ('Lip pruritus', 318),
#  ('Full blood count abnormal', 318),
#  ('Carbon dioxide normal', 317),
#  ('Immune thrombocytopenia', 317),
#  ('Vaccination site urticaria', 316),
#  ('Polymerase chain reaction', 315),
#  ('Influenza virus test', 314),
#  ('Supraventricular tachycardia', 314),
#  ('Adverse drug reaction', 313),
#  ('Sinus headache', 312),
#  ('Weight increased', 312),
#  ('Blood bilirubin normal', 311),
#  ('Blood culture negative', 310),
#  ('Acne', 309),
#  ('Ear infection', 309),
#  ('Tension headache', 308),
#  ('Antinuclear antibody negative', 308),
#  ('Troponin I increased', 307),
#  ('Ultrasound Doppler normal', 306),
#  ('Extrasystoles', 305),
#  ('Sciatica', 305),
#  ('Activated partial thromboplastin time', 305),
#  ('Liver function test', 305),
#  ('Colonoscopy', 304),
#  ('Gastrointestinal pain', 303),
#  ('Electromyogram', 303),
#  ('Product use issue', 303),
#  ('Stress', 301),
#  ('Respiratory arrest', 299),
#  ('Emotional distress', 299),
#  ('Blood creatine phosphokinase', 299),
#  ('Eructation', 298),
#  ('Chronic obstructive pulmonary disease', 298),
#  ('Feeling drunk', 296),
#  ('Pregnancy test negative', 296),
#  ('Aspartate aminotransferase normal', 294),
#  ('Blood magnesium normal', 294),
#  ('Vaccination site discolouration', 294),
#  ('Dermatitis', 293),
#  ('Blindness unilateral', 293),
#  ('Troponin I', 292),
#  ('Skin mass', 292),
#  ('X-ray limb', 290),
#  ('Autoimmune disorder', 289),
#  ('Oral mucosal blistering', 289),
#  ('Ischaemic stroke', 288),
#  ('Red blood cell count normal', 287),
#  ('Injection site vesicles', 287),
#  ('Depressed level of consciousness', 287),
#  ('Cardiomegaly', 287),
#  ('Haematuria', 286),
#  ('Differential white blood cell count normal', 284),
#  ('Photopsia', 284),
#  ('Blood calcium normal', 283),
#  ('Mouth ulceration', 283),
#  ('Urine analysis abnormal', 282),
#  ('Fear of injection', 280),
#  ('Pelvic pain', 280),
#  ('Injection site irritation', 280),
#  ('Posture abnormal', 278),
#  ('Eating disorder', 278),
#  ('Eye haemorrhage', 276),
#  ('Psoriasis', 276),
#  ('Hepatic enzyme increased', 276),
#  ('Pulse abnormal', 275),
#  ('Red cell distribution width normal', 275),
#  ('Mydriasis', 275),
#  ('Cardiac failure', 275),
#  ('Mean cell haemoglobin concentration normal', 273),
#  ('International normalised ratio normal', 272),
#  ('Thyroid function test', 272),
#  ('Scab', 271),
#  ('Gingival pain', 271),
#  ('Fluid retention', 270),
#  ('Formication', 268),
#  ('Aphthous ulcer', 268),
#  ('Vaccination site movement impairment', 268),
#  ('Rash maculo-papular', 266),
#  ('Skin laceration', 266),
#  ('Protein total normal', 265),
#  ('Renal failure', 263),
#  ('Cardioversion', 262),
#  ('Allergy to vaccine', 261),
#  ('Odynophagia', 260),
#  ('Haemoglobin', 259),
#  ('Local reaction', 258),
#  ('Atelectasis', 257),
#  ('Gaze palsy', 256),
#  ('Antinuclear antibody positive', 255),
#  ('Deafness neurosensory', 255),
#  ('Blood alkaline phosphatase increased', 255),
#  ('Surgery', 255),
#  ('Streptococcus test', 254),
#  ('Coordination abnormal', 254),
#  ('Transfusion', 254),
#  ('Facial discomfort', 252),
#  ('Bursitis', 250),
#  ('Brain natriuretic peptide', 249),
#  ('Glomerular filtration rate decreased', 248),
#  ('Nasal discomfort', 248),
#  ('Periarthritis', 248),
#  ('Cerebral infarction', 248),
#  ('Vaccination site haemorrhage', 246),
#  ('Needle issue', 246),
#  ('Autopsy', 246),
#  ('Therapy non-responder', 246),
#  ('Faeces discoloured', 244),
#  ('Leukocytosis', 244),
#  ('Magnetic resonance imaging spinal', 244),
#  ('Neurological examination', 243),
#  ('Fibromyalgia', 243),
#  ('Computerised tomogram thorax normal', 242),
#  ('Cheilitis', 242),
#  ('Muscle strain', 242),
#  ('Incoherent', 241),
#  ('Blood albumin normal', 239),
#  ('Endoscopy', 239),
#  ('Blood creatine phosphokinase normal', 238),
#  ('Motor dysfunction', 237),
#  ('Wrong technique in product usage process', 237),
#  ('Ear congestion', 236),
#  ('Mean cell haemoglobin normal', 235),
#  ('Lipase', 235),
#  ('Breast mass', 235),
#  ('International normalised ratio increased', 235),
#  ('Catheterisation cardiac normal', 235),
#  ('Skin disorder', 234),
#  ('Abnormal behaviour', 234),
#  ('Post-acute COVID-19 syndrome', 234),
#  ('Thyroid function test normal', 233),
#  ('Monoplegia', 233),
#  ('Gastrointestinal haemorrhage', 232),
#  ('Sudden hearing loss', 232),
#  ('Glomerular filtration rate', 231),
#  ('Lipids', 231),
#  ('Blood bilirubin increased', 231),
#  ('Hemiplegia', 230),
#  ('Respiratory syncytial virus test negative', 229),
#  ('Electroencephalogram normal', 229),
#  ('Eyelid ptosis', 229),
#  ('Rheumatoid factor negative', 229),
#  ('Muscle contractions involuntary', 228),
#  ('Lip blister', 228),
#  ('Pulse absent', 226),
#  ('Pleuritic pain', 225),
#  ('Lung disorder', 224),
#  ('Ear pruritus', 223),
#  ('Face injury', 223),
#  ('Limb mass', 223),
#  ('Cardio-respiratory arrest', 223),
#  ('Panic reaction', 222),
#  ('Muscle rigidity', 222),
#  ('Rheumatoid factor', 221),
#  ('Diabetes mellitus', 220),
#  ('Nephrolithiasis', 220),
#  ('Liver function test normal', 219),
#  ('Brain natriuretic peptide normal', 219),
#  ('Acoustic stimulation tests normal', 219),
#  ('Vitamin D', 218),
#  ('Salivary hypersecretion', 217),
#  ('Incontinence', 216),
#  ('Vaccination site discomfort', 216),
#  ('Euphoric mood', 215),
#  ('Lymphocyte percentage decreased', 215),
#  ('Neutrophil count increased', 215),
#  ('Audiogram', 215),
#  ('Exercise tolerance decreased', 214),
#  ('Blood thyroid stimulating hormone decreased', 213),
#  ('Neutrophil percentage increased', 213),
#  ('Lip pain', 213),
#  ('Upper respiratory tract infection', 213),
#  ('Dermatitis allergic', 212),
#  ('Rectal haemorrhage', 212),
#  ('Magnetic resonance imaging spinal abnormal', 212),
#  ('Bilevel positive airway pressure', 211),
#  ('Vitamin B12 normal', 211),
#  ('Platelet count increased', 210),
#  ('Anal incontinence', 209),
#  ('Nerve injury', 209),
#  ('Frequent bowel movements', 208),
#  ('Photosensitivity reaction', 208),
#  ('Skin abrasion', 208),
#  ('Restless legs syndrome', 207),
#  ('Gingival bleeding', 207),
#  ('Thrombectomy', 207),
#  ('Hyperglycaemia', 205),
#  ('Vertigo positional', 205),
#  ('Blood calcium decreased', 204),
#  ('Neck mass', 204),
#  ('Suicidal ideation', 203),
#  ('Tryptase', 202),
#  ('Thrombophlebitis superficial', 202),
#  ('Scan', 202),
#  ('Catheterisation cardiac abnormal', 201),
#  ('Diverticulitis', 201),
#  ('Pain assessment', 201),
#  ('Medication error', 201),
#  ('Injection site oedema', 199),
#  ('Pregnancy', 199),
#  ('Nervous system disorder', 199),
#  ('Hypotonia', 198),
#  ('Monocyte percentage', 197),
#  ('Encephalopathy', 197),
#  ('Body temperature fluctuation', 197),
#  ('Tension', 196),
#  ('Micturition urgency', 195),
#  ('Blood creatinine', 194),
#  ('Herpes simplex', 193),
#  ('Shoulder injury related to vaccine administration', 193),
#  ('Hypoglycaemia', 192),
#  ('Viral test', 192),
#  ('Liver function test increased', 192),
#  ('Haematoma', 192),
#  ('Anion gap', 191),
#  ('Lymphadenitis', 191),
#  ('Immunology test', 191),
#  ('Mean platelet volume normal', 190),
#  ('Allergy test', 190),
#  ('Troponin I normal', 190),
#  ('Trismus', 190),
#  ('Systemic inflammatory response syndrome', 190),
#  ('Polymyalgia rheumatica', 190),
#  ('Tendonitis', 189),
#  ('Colitis', 188),
#  ('Vitamin B12', 187),
#  ('Conjunctivitis', 186),
#  ('Computerised tomogram pelvis', 186),
#  ('Joint injury', 185),
#  ('Pulmonary function test', 185),
#  ('Lymphoedema', 184),
#  ('Drooling', 184),
#  ('Vaccination site inflammation', 184),
#  ('Lymphocyte count decreased', 183),
#  ('Blood glucose abnormal', 183),
#  ('Blood albumin decreased', 183),
#  ('Respiratory disorder', 183),
#  ('Scan with contrast normal', 182),
#  ('Neutrophil count', 181),
#  ('Cardiac stress test normal', 181),
#  ('Skin induration', 181),
#  ('Urinary retention', 181),
#  ('Hypokalaemia', 180),
#  ('Eosinophil percentage', 179),
#  ('Pityriasis rosea', 179),
#  ('Drug hypersensitivity', 179),
#  ('Bed rest', 178),
#  ('Culture urine negative', 178),
#  ('Systemic lupus erythematosus', 178),
#  ('Cardiac imaging procedure abnormal', 177),
#  ('Eyelid function disorder', 176),
#  ('Angiogram normal', 176),
#  ('Gingival swelling', 176),
#  ('Angiogram abnormal', 176),
#  ('Pulmonary mass', 176),
#  ('Renal impairment', 176),
#  ('Purpura', 175),
#  ('Trigeminal neuralgia', 174),
#  ('Visual field defect', 173),
#  ('Blood cholesterol increased', 173),
#  ('X-ray limb normal', 173),
#  ('Blood cholesterol', 173),
#  ('Respiratory rate', 173),
#  ('Haematemesis', 172),
#  ('Body height', 171),
#  ('Blood immunoglobulin G', 171),
#  ('Lymphocyte count normal', 170),
#  ('Arthropathy', 170),
#  ('Anger', 170),
#  ('Disease recurrence', 170),
#  ('Human chorionic gonadotropin', 169),
#  ('Hunger', 169),
#  ('Carbon dioxide decreased', 169),
#  ('Prothrombin time normal', 169),
#  ('X-ray abnormal', 169),
#  ('Spinal X-ray', 169),
#  ('Cystitis', 169),
#  ('Immune system disorder', 168),
#  ('Myelitis transverse', 168),
#  ('Viral infection', 167),
#  ('Atrial flutter', 167),
#  ('Lumbar puncture abnormal', 167),
#  ('Cerebral venous sinus thrombosis', 167),
#  ('Angiogram cerebral abnormal', 166),
#  ('Chapped lips', 166),
#  ('Muscle swelling', 166),
#  ('Choking', 166),
#  ('Anaphylactic shock', 166),
#  ('Ultrasound scan vagina', 166),
#  ('Neutrophil count normal', 165),
#  ('Blood lactic acid increased', 165),
#  ('Ventricular tachycardia', 165),
#  ('Exposure via skin contact', 165),
#  ('Mastication disorder', 165),
#  ('Cerebral thrombosis', 165),
#  ('Tonsillar hypertrophy', 164),
#  ('Vasculitis', 164),
#  ('HIV test negative', 164),
#  ('Borrelia test negative', 163),
#  ('Ejection fraction', 163),
#  ('Eye discharge', 162),
#  ('Temperature intolerance', 162),
#  ('Culture', 162),
#  ('Concussion', 162),
#  ('Overdose', 162),
#  ('Maternal exposure during breast feeding', 161),
#  ('Vaccination site lymphadenopathy', 161),
#  ('Circumstance or information capable of leading to medication error', 160),
#  ('Motion sickness', 160),
#  ('Altered state of consciousness', 160),
#  ('Blood electrolytes normal', 160),
#  ('Sinus operation', 159),
#  ('Nerve compression', 159),
#  ('Stent placement', 159),
#  ('CSF protein increased', 159),
#  ('Viral test negative', 158),
#  ('Mental disorder', 158),
#  ('Skin sensitisation', 157),
#  ('Blood potassium', 157),
#  ('Eosinophil count normal', 156),
#  ('Angiogram cerebral normal', 156),
#  ('Inflammatory marker increased', 156),
#  ('Pleurisy', 155),
#  ('Herpes virus infection', 155),
#  ('Ejection fraction normal', 155),
#  ('Rhabdomyolysis', 155),
#  ('Cardiac discomfort', 154),
#  ('Scratch', 154),
#  ('Pancreatitis', 154),
#  ('Erythema multiforme', 154),
#  ('Multiple sclerosis', 154),
#  ('Livedo reticularis', 153),
#  ('Serum ferritin increased', 153),
#  ('Glycosylated haemoglobin increased', 153),
#  ('Coronary arterial stent insertion', 153),
#  ('Blindness transient', 152),
#  ('Lymphocyte count', 152),
#  ('Bowel movement irregularity', 151),
#  ('Respiratory symptom', 151),
#  ('Exposure via breast milk', 151),
#  ('Tongue discolouration', 151),
#  ('Intentional product use issue', 151),
#  ('Migraine with aura', 150),
#  ('Audiogram abnormal', 150),
#  ('Dermatitis contact', 150),
#  ('Nerve conduction studies', 150),
#  ('Neutrophil count decreased', 149),
#  ('Injection site hypersensitivity', 149),
#  ('Monocyte percentage increased', 148),
#  ('Body temperature abnormal', 148),
#  ('Scar', 148),
#  ('Emotional disorder', 148),
#  ('Musculoskeletal disorder', 147),
#  ('Basophil percentage', 147),
#  ('Monocyte count increased', 147),
#  ('Staring', 147),
#  ('Procalcitonin', 147),
#  ('Sinus rhythm', 147),
#  ('Magnetic resonance imaging spinal normal', 147),
#  ('Lymphocyte percentage', 146),
#  ('Lip dry', 146),
#  ('Pharyngeal erythema', 145),
#  ('Testicular pain', 145),
#  ('Dementia', 145),
#  ('Costochondritis', 145),
#  ('Fungal infection', 145),
#  ('Orthostatic hypotension', 144),
#  ('Glomerular filtration rate normal', 144),
#  ('Myocardial necrosis marker', 144),
#  ('Middle ear effusion', 144),
#  ('Prothrombin time prolonged', 143),
#  ('Dysphemia', 142),
#  ('Energy increased', 142),
#  ('Blood gases', 142),
#  ('Road traffic accident', 142),
#  ('Injury', 141),
#  ('Uterine dilation and curettage', 141),
#  ('Vaccination error', 141),
#  ('Ataxia', 140),
#  ('Diarrhoea haemorrhagic', 140),
#  ('Muscle discomfort', 140),
#  ('Lipase normal', 140),
#  ('Wheelchair user', 139),
#  ('Eosinophil count decreased', 138),
#  ('Blood chloride increased', 138),
#  ('Pneumonitis', 137),
#  ('Hospitalisation', 137),
#  ('Basophil count decreased', 136),
#  ('Coronary artery disease', 136),
#  ('Mood altered', 136),
#  ('Immature granulocyte count', 136),
#  ('Vasodilatation', 136),
#  ('Tendon pain', 135),
#  ('Monocyte count normal', 134),
#  ('Rash morbilliform', 134),
#  ('Cardiovascular evaluation', 134),
#  ('Oral mucosal eruption', 134),
#  ('Irritable bowel syndrome', 134),
#  ('Blood immunoglobulin M', 134),
#  ('Lumbar puncture normal', 133),
#  ('Platelet transfusion', 133),
#  ('Oral disorder', 133),
#  ('Brain oedema', 133),
#  ('Osteoarthritis', 132),
#  ('Jaundice', 132),
#  ('Influenza A virus test', 131),
#  ('Ultrasound antenatal screen abnormal', 131),
#  ('Ultrasound breast', 131),
#  ('Ear, nose and throat examination', 131),
#  ('Abnormal sensation in eye', 130),
#  ('Rash pustular', 130),
#  ('Refusal of treatment by patient', 130),
#  ...]

# %%
covid_side_effect_list = []

# 코로나 백신 부작용 추출
for i in range(len(covid_rank_list)):
    if covid_rank_list[i][1] >= 10:
        covid_side_effect_list.append(covid_rank_list[i][0])

# %%
f = open('./dataset/covid_side_effect_list.txt', 'w')
f.write('\n'.join(covid_side_effect_list))
f.close()

# %% [markdown]
# # 모든 백신 증상 부작용 목록생성

# %%
SYMPTOMS_df = pd.DataFrame()
VAX_df = pd.DataFrame()

startYear = 1990 # 통합할 데이터의 시작연도
numOfFiles = 32 # 파일의 갯수
for i in tqdm(range(0, numOfFiles, 1)):
    symptoms_df = pd.read_csv('./dataset/AllVAERSDataCSVS/' + str(startYear+i) + 'VAERSSYMPTOMS.csv', encoding='latin')
    vax_df = pd.read_csv('./dataset/AllVAERSDataCSVS/' + str(startYear+i) + 'VAERSVAX.csv', encoding='latin')
    
    SYMPTOMS_df = pd.concat([SYMPTOMS_df, symptoms_df])
    VAX_df = pd.concat([VAX_df, vax_df])
    
    del symptoms_df
    del vax_df
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████| 32/32 [00:05<00:00,  5.61it/s]

# %%
# 필요한 피처만 남기고 제거
SYMPTOMS_df = SYMPTOMS_df[['VAERS_ID', 'SYMPTOM1', 'SYMPTOM2', 'SYMPTOM3', 'SYMPTOM4', 'SYMPTOM5']]
VAX_df = VAX_df[['VAERS_ID', 'VAX_TYPE']]

# %%
# VAERS_ID 기준으로 inner join
VAERS_df = pd.merge(SYMPTOMS_df, VAX_df, how='inner', on='VAERS_ID')
VAERS_df.head()
# Out:
#    VAERS_ID   SYMPTOM1               SYMPTOM2                 SYMPTOM3  \
# 0     25001  Agitation                    NaN                      NaN
# 1     25003   Delirium            Hypokinesia                Hypotonia
# 2     25003   Delirium            Hypokinesia                Hypotonia
# 3     25004     Chills     Dermatitis contact           Oedema genital
# 4     25005  Arthritis  Injection site oedema  Injection site reaction
#
#       SYMPTOM4 SYMPTOM5 VAX_TYPE
# 0          NaN      NaN      DTP
# 1          NaN      NaN      DTP
# 2          NaN      NaN      OPV
# 3  Pelvic pain      NaN      OPV
# 4          NaN      NaN       TD

# %%
all_symptom_2list = VAERS_df[['SYMPTOM1', 'SYMPTOM2', 'SYMPTOM3', 'SYMPTOM4', 'SYMPTOM5']].values

# %%
# 2차원 리스트를 1차원으로
all_symptom_list = [element for array in all_symptom_2list for element in array]

# %%
all_rank_list = collections.Counter(all_symptom_list).most_common()[1:]
all_rank_list
# Out:
# [('Pyrexia', 282489),
#  ('Headache', 163599),
#  ('Injection site erythema', 162941),
#  ('Pain', 152296),
#  ('Injection site pain', 123844),
#  ('Fatigue', 119372),
#  ('Chills', 116802),
#  ('Rash', 112731),
#  ('Injection site swelling', 109809),
#  ('Nausea', 103795),
#  ('Pain in extremity', 102071),
#  ('Dizziness', 101419),
#  ('Erythema', 100870),
#  ('No adverse event', 89461),
#  ('Pruritus', 79044),
#  ('Vomiting', 74242),
#  ('Urticaria', 69909),
#  ('Injection site warmth', 67053),
#  ('Myalgia', 66561),
#  ('Arthralgia', 57929),
#  ('Dyspnoea', 55409),
#  ('Asthenia', 47609),
#  ('Diarrhoea', 46330),
#  ('Malaise', 40349),
#  ('Injection site oedema', 38734),
#  ('Swelling', 37831),
#  ('Injection site pruritus', 35975),
#  ('Paraesthesia', 35973),
#  ('Cough', 34090),
#  ('Syncope', 33757),
#  ('Hyperhidrosis', 33143),
#  ('Injection site induration', 31928),
#  ('Skin warm', 31418),
#  ('Crying', 30828),
#  ('Hypoaesthesia', 30514),
#  ('Incorrect product storage', 30416),
#  ('Injection site hypersensitivity', 29869),
#  ('Tremor', 28755),
#  ('Peripheral swelling', 28725),
#  ('Feeling hot', 28119),
#  ('Lymphadenopathy', 27213),
#  ('Pallor', 26691),
#  ('Injection site rash', 26348),
#  ('Rash erythematous', 26193),
#  ('Herpes zoster', 25610),
#  ('Convulsion', 25598),
#  ('Agitation', 25495),
#  ('Injection site reaction', 25186),
#  ('Feeling abnormal', 25027),
#  ('Oedema peripheral', 24966),
#  ('Chest pain', 23945),
#  ('Product storage error', 23807),
#  ('Injection site mass', 21462),
#  ('Screaming', 21393),
#  ('Irritability', 21358),
#  ('Loss of consciousness', 21255),
#  ('Cellulitis', 20924),
#  ('Decreased appetite', 19917),
#  ('Back pain', 19714),
#  ('Somnolence', 19693),
#  ('Body temperature increased', 19555),
#  ('Infection', 19156),
#  ('COVID-19', 18327),
#  ('Neck pain', 18038),
#  ('Influenza like illness', 17887),
#  ('Tenderness', 17325),
#  ('Blood test', 17103),
#  ('Drug ineffective', 17091),
#  ('Vasodilatation', 17009),
#  ('Condition aggravated', 16720),
#  ('Chest discomfort', 16625),
#  ('Lethargy', 16578),
#  ('Insomnia', 16016),
#  ('Immediate post-injection reaction', 15961),
#  ('Heart rate increased', 15912),
#  ('Rash pruritic', 15780),
#  ('Mobility decreased', 15612),
#  ('Musculoskeletal stiffness', 15080),
#  ('Oropharyngeal pain', 14919),
#  ('Hypersensitivity', 14440),
#  ('Palpitations', 14173),
#  ('Abdominal pain', 14070),
#  ('Unevaluable event', 13992),
#  ('SARS-CoV-2 test positive', 13702),
#  ('Muscular weakness', 13353),
#  ('Tinnitus', 13043),
#  ('Oedema', 13041),
#  ('Vaccination site pain', 12929),
#  ('Rash maculo-papular', 12896),
#  ('Gait disturbance', 12821),
#  ('Fall', 12733),
#  ('Flushing', 12538),
#  ('Rash macular', 12527),
#  ('Swelling face', 12473),
#  ('Blister', 12318),
#  ('Abdominal pain upper', 12035),
#  ('Full blood count', 11975),
#  ('Product administered to patient of inappropriate age', 11507),
#  ('Inappropriate schedule of drug administration', 11500),
#  ('Rhinorrhoea', 11419),
#  ('Expired product administered', 11204),
#  ('Muscle spasms', 11152),
#  ('Rash papular', 11142),
#  ('Hypotonia', 10902),
#  ('Electrocardiogram', 10902),
#  ('SARS-CoV-2 test', 10818),
#  ('Sleep disorder', 10761),
#  ('Rash vesicular', 10496),
#  ('Rash generalised', 10455),
#  ('Injected limb mobility decreased', 10430),
#  ('Laboratory test', 10104),
#  ('Anxiety', 9914),
#  ('Wrong drug administered', 9834),
#  ('Burning sensation', 9731),
#  ('Migraine', 9673),
#  ('Death', 9463),
#  ('Throat tightness', 9228),
#  ('Vision blurred', 9188),
#  ('Feeling cold', 9099),
#  ('Febrile convulsion', 9021),
#  ('Unresponsive to stimuli', 8923),
#  ('Induration', 8758),
#  ('Vertigo', 8743),
#  ('Computerised tomogram', 8733),
#  ('Contusion', 8693),
#  ('Wheezing', 8539),
#  ('Hypokinesia', 8473),
#  ('Extra dose administered', 8282),
#  ('Tachycardia', 8273),
#  ('Cyanosis', 8265),
#  ('Anorexia', 8246),
#  ('Inappropriate schedule of product administration', 8115),
#  ('Lip swelling', 8031),
#  ('Seizure', 8014),
#  ('Body temperature', 7910),
#  ('Dermatitis bullous', 7900),
#  ('Hypertension', 7854),
#  ('Nasal congestion', 7843),
#  ('Local reaction', 7837),
#  ('Abdominal discomfort', 7730),
#  ('Dysphagia', 7701),
#  ('Musculoskeletal pain', 7637),
#  ('Discomfort', 7563),
#  ('Full blood count normal', 7562),
#  ('Throat irritation', 7554),
#  ('SARS-CoV-2 test negative', 7524),
#  ('Injection site urticaria', 7505),
#  ('Confusional state', 7482),
#  ('Paraesthesia oral', 7452),
#  ('Muscle twitching', 7401),
#  ('Blood pressure increased', 7374),
#  ('Incorrect dose administered', 7334),
#  ('Vaccination complication', 7332),
#  ('Skin discolouration', 7331),
#  ('Metabolic function test', 7300),
#  ('Incorrect storage of drug', 7195),
#  ('Viral infection', 7180),
#  ('Chest X-ray', 7051),
#  ('Laboratory test abnormal', 7042),
#  ('Influenza', 6982),
#  ('Stupor', 6943),
#  ('Cold sweat', 6840),
#  ('Dyskinesia', 6702),
#  ('Eye swelling', 6659),
#  ('Hypotension', 6591),
#  ('Vaccination site swelling', 6513),
#  ('Electrocardiogram normal', 6411),
#  ('Vaccination site erythema', 6401),
#  ('Impaired work ability', 6369),
#  ('Exposure during pregnancy', 6363),
#  ('Pneumonia', 6358),
#  ('Drug administered to patient of inappropriate age', 6175),
#  ('Dehydration', 6172),
#  ('Injection site inflammation', 6063),
#  ('Pharyngitis', 6010),
#  ('Inflammation', 5978),
#  ('Axillary pain', 5956),
#  ('Face oedema', 5851),
#  ('White blood cell count increased', 5847),
#  ('Apnoea', 5714),
#  ('Swollen tongue', 5685),
#  ('Joint swelling', 5664),
#  ('Limb discomfort', 5657),
#  ('Blood test normal', 5640),
#  ('Urine analysis', 5615),
#  ('Gaze palsy', 5505),
#  ('Loss of personal independence in daily activities', 5495),
#  ('Local swelling', 5485),
#  ('Balance disorder', 5474),
#  ('Chest X-ray normal', 5443),
#  ('X-ray', 5326),
#  ('Skin lesion', 5320),
#  ('Otitis media', 5286),
#  ('Injection site cellulitis', 5245),
#  ('Dysgeusia', 5234),
#  ('Hypoaesthesia oral', 5232),
#  ('Laboratory test normal', 5155),
#  ('Ear pain', 5075),
#  ('Injection site bruising', 5038),
#  ('Injection site nodule', 5008),
#  ('Visual impairment', 4978),
#  ('Injection site vesicles', 4924),
#  ('Presyncope', 4923),
#  ('Nasopharyngitis', 4841),
#  ('Rhinitis', 4762),
#  ('Expired drug administered', 4752),
#  ('Lymph node pain', 4732),
#  ('Joint range of motion decreased', 4673),
#  ('Interchange of vaccine products', 4673),
#  ('Guillain-Barre syndrome', 4637),
#  ('Speech disorder', 4634),
#  ('Skin ulcer', 4566),
#  ('Ultrasound scan', 4521),
#  ('Computerised tomogram normal', 4502),
#  ('Eye pain', 4462),
#  ('Asthma', 4453),
#  ('Respiratory tract congestion', 4443),
#  ('Head injury', 4361),
#  ('Magnetic resonance imaging', 4294),
#  ('Hot flush', 4289),
#  ('Ocular hyperaemia', 4178),
#  ('Abnormal behaviour', 4168),
#  ('Haematochezia', 4167),
#  ('Hypertonia', 4164),
#  ('Intussusception', 4160),
#  ('Eye movement disorder', 4147),
#  ('Medication error', 4131),
#  ('Vaccination site warmth', 4123),
#  ('Dysphonia', 4113),
#  ('Hypersomnia', 4111),
#  ('Underdose', 3967),
#  ('Pharyngeal swelling', 3960),
#  ('Vaccination failure', 3932),
#  ('Vaccine positive rechallenge', 3923),
#  ('Anaphylactic reaction', 3913),
#  ('Vaccination site pruritus', 3909),
#  ('Urine analysis normal', 3869),
#  ('Echocardiogram', 3773),
#  ('Wrong product administered', 3722),
#  ('Illness', 3700),
#  ('Ageusia', 3685),
#  ('Staring', 3625),
#  ('Blood glucose normal', 3603),
#  ('Disorientation', 3573),
#  ('Petechiae', 3542),
#  ('Intensive care', 3516),
#  ('Neuralgia', 3501),
#  ('Night sweats', 3493),
#  ('Nervousness', 3480),
#  ('Varicella', 3442),
#  ('Nuclear magnetic resonance imaging', 3412),
#  ('Dysstasia', 3378),
#  ('Weight decreased', 3361),
#  ('Varicella post vaccine', 3347),
#  ('Activities of daily living impaired', 3341),
#  ('Thrombosis', 3313),
#  ('Arthritis', 3284),
#  ('Epistaxis', 3229),
#  ('Cerebrovascular accident', 3140),
#  ('Blood pressure measurement', 3127),
#  ('Platelet count decreased', 3111),
#  ('Disturbance in attention', 3106),
#  ('Sudden infant death syndrome', 3099),
#  ('Aphasia', 3098),
#  ('Computerised tomogram head', 3069),
#  ('Bone pain', 3059),
#  ('Photophobia', 3055),
#  ('Autism', 3051),
#  ('Injection site discolouration', 3048),
#  ('Drug exposure during pregnancy', 3041),
#  ('Blood glucose increased', 3007),
#  ('Facial paralysis', 3003),
#  ("Bell's palsy", 2999),
#  ('Sneezing', 2973),
#  ('C-reactive protein increased', 2907),
#  ('Heavy menstrual bleeding', 2845),
#  ('Lumbar puncture', 2840),
#  ('Vaccination site rash', 2840),
#  ('Head discomfort', 2838),
#  ('Erythema multiforme', 2831),
#  ('Electrocardiogram abnormal', 2829),
#  ('Muscle tightness', 2817),
#  ('Nodule', 2810),
#  ('Heart rate', 2780),
#  ('Pulmonary embolism', 2769),
#  ('Blood culture negative', 2753),
#  ('Dry mouth', 2725),
#  ('Pain in jaw', 2718),
#  ('Anosmia', 2716),
#  ('Retching', 2704),
#  ('Red blood cell sedimentation rate increased', 2676),
#  ('Lacrimation increased', 2633),
#  ('Hypoxia', 2629),
#  ('Electroencephalogram', 2604),
#  ('Metabolic function test normal', 2593),
#  ('Blood pressure decreased', 2564),
#  ('Constipation', 2563),
#  ('Ear discomfort', 2551),
#  ('Urinary tract infection', 2518),
#  ('Skin nodule', 2516),
#  ('Movement disorder', 2516),
#  ('Mass', 2463),
#  ('Peripheral coldness', 2455),
#  ('Chest X-ray abnormal', 2448),
#  ('Dyspepsia', 2439),
#  ('Eye pruritus', 2420),
#  ('Product preparation issue', 2420),
#  ('Joint stiffness', 2409),
#  ('Menstruation irregular', 2397),
#  ('Gait inability', 2385),
#  ('Pharyngeal oedema', 2380),
#  ('Electroencephalogram normal', 2379),
#  ('Leukocytosis', 2378),
#  ('Ecchymosis', 2372),
#  ('Influenza virus test negative', 2365),
#  ('Amnesia', 2361),
#  ('Pharyngolaryngeal pain', 2361),
#  ('Sinusitis', 2325),
#  ('Pruritus generalised', 2317),
#  ('Upper respiratory tract infection', 2298),
#  ('White blood cell count normal', 2284),
#  ('Myocarditis', 2277),
#  ('Dysarthria', 2269),
#  ('Skin burning sensation', 2265),
#  ('Coma', 2263),
#  ('Incorrect route of drug administration', 2259),
#  ('Pain of skin', 2227),
#  ('Abdominal distension', 2201),
#  ('Cardiac arrest', 2189),
#  ('Urinary incontinence', 2181),
#  ('Electroencephalogram abnormal', 2173),
#  ('Grand mal convulsion', 2173),
#  ('Injection site haemorrhage', 2173),
#  ('Alopecia', 2173),
#  ('Rash morbilliform', 2169),
#  ('Atrial fibrillation', 2155),
#  ('Deafness', 2150),
#  ('Streptococcus test negative', 2137),
#  ('Sepsis', 2135),
#  ('Memory impairment', 2128),
#  ('Abasia', 2113),
#  ('Skin exfoliation', 2108),
#  ('Haemoglobin normal', 2101),
#  ('Troponin increased', 2091),
#  ('Echocardiogram normal', 2082),
#  ('Scab', 2079),
#  ('Deep vein thrombosis', 2076),
#  ('Hyperventilation', 2063),
#  ('Depression', 2059),
#  ('Paralysis', 2054),
#  ('Conjunctivitis', 2052),
#  ('Immunoglobulin therapy', 2031),
#  ('Blood culture', 2029),
#  ('Eye irritation', 2019),
#  ('Oxygen saturation decreased', 1999),
#  ('Poor quality product administered', 1995),
#  ('Gastrointestinal disorder', 1993),
#  ('Platelet count normal', 1974),
#  ('Anaemia', 1970),
#  ('Haemorrhage', 1969),
#  ('Thirst', 1965),
#  ('Rash pustular', 1961),
#  ('Posture abnormal', 1950),
#  ('Restlessness', 1940),
#  ('Thrombocytopenia', 1938),
#  ('Injection site discomfort', 1922),
#  ('Eye disorder', 1913),
#  ('Respiratory disorder', 1911),
#  ('Eczema', 1907),
#  ('Respiratory arrest', 1906),
#  ('Polymerase chain reaction', 1905),
#  ('Nuclear magnetic resonance imaging normal', 1897),
#  ('Menstrual disorder', 1896),
#  ('Computerised tomogram head normal', 1863),
#  ('Bronchitis', 1850),
#  ('Oral herpes', 1845),
#  ('Dry skin', 1834),
#  ('Eyelid oedema', 1830),
#  ('Product dose omission issue', 1824),
#  ('Taste disorder', 1821),
#  ('Red blood cell sedimentation rate normal', 1813),
#  ('Coordination abnormal', 1812),
#  ('Incorrect route of product administration', 1812),
#  ('Aspartate aminotransferase increased', 1805),
#  ('Emotional distress', 1803),
#  ('Blindness', 1801),
#  ('Productive cough', 1800),
#  ('Haemoglobin decreased', 1785),
#  ('Hypoacusis', 1777),
#  ('Hyperaesthesia', 1774),
#  ('Syringe issue', 1771),
#  ('Breast pain', 1770),
#  ('Computerised tomogram abnormal', 1765),
#  ('Depressed level of consciousness', 1742),
#  ('Heart rate irregular', 1742),
#  ('Endotracheal intubation', 1739),
#  ('Bradycardia', 1738),
#  ('Sensory disturbance', 1735),
#  ('Seizure like phenomena', 1725),
#  ('Facial pain', 1724),
#  ('Alanine aminotransferase increased', 1718),
#  ('Nervous system disorder', 1708),
#  ('Myasthenic syndrome', 1707),
#  ('Facial palsy', 1700),
#  ('Differential white blood cell count', 1694),
#  ('Injection site abscess', 1684),
#  ('Heart rate decreased', 1672),
#  ('Pericarditis', 1670),
#  ('Bacterial infection', 1668),
#  ('Culture urine negative', 1653),
#  ('Ultrasound scan normal', 1649),
#  ('Musculoskeletal discomfort', 1646),
#  ('Troponin', 1646),
#  ('Vaccination site induration', 1637),
#  ('Neuropathy peripheral', 1636),
#  ('Hallucination', 1633),
#  ('Feeling of body temperature change', 1632),
#  ('Abortion spontaneous', 1630),
#  ('Adverse event', 1622),
#  ('Injection site haematoma', 1621),
#  ('Surgery', 1618),
#  ('Blood glucose', 1613),
#  ('Flatulence', 1611),
#  ('Adverse reaction', 1599),
#  ('C-reactive protein', 1596),
#  ('Gastrooesophageal reflux disease', 1584),
#  ('X-ray normal', 1566),
#  ('Incomplete course of vaccination', 1560),
#  ('Product preparation error', 1543),
#  ('Ultrasound Doppler', 1537),
#  ('Product administered at inappropriate site', 1520),
#  ('Poor quality sleep', 1508),
#  ('Skin reaction', 1507),
#  ('Injury', 1502),
#  ('Diplopia', 1494),
#  ('Angioedema', 1483),
#  ('Ear infection', 1480),
#  ('Myocardial infarction', 1474),
#  ('Sensation of foreign body', 1460),
#  ('Lung disorder', 1453),
#  ('Ultrasound scan abnormal', 1453),
#  ('Vaccination site reaction', 1448),
#  ('C-reactive protein normal', 1445),
#  ('Cognitive disorder', 1435),
#  ('Vital signs measurement', 1429),
#  ('Blood thyroid stimulating hormone', 1415),
#  ('Meningitis', 1409),
#  ('Musculoskeletal chest pain', 1401),
#  ('Anticoagulant therapy', 1396),
#  ('Diet refusal', 1392),
#  ('Vaginal haemorrhage', 1384),
#  ('Osteoarthritis', 1382),
#  ('Oropharyngeal discomfort', 1375),
#  ('Mental status changes', 1371),
#  ('Feeding disorder', 1361),
#  ('Respiratory distress', 1353),
#  ('Red blood cell sedimentation rate', 1346),
#  ('Respiratory rate increased', 1343),
#  ('Faeces discoloured', 1340),
#  ('Blood test abnormal', 1338),
#  ('Dysmenorrhoea', 1333),
#  ('Haematocrit normal', 1332),
#  ('Maternal exposure during pregnancy', 1321),
#  ('Encephalitis', 1316),
#  ('White blood cell count decreased', 1309),
#  ('Resuscitation', 1306),
#  ('Nuclear magnetic resonance imaging abnormal', 1305),
#  ('Sinus congestion', 1297),
#  ('Magnetic resonance imaging head', 1297),
#  ('Stomatitis', 1296),
#  ('Panic attack', 1289),
#  ('Abscess', 1275),
#  ('Skin irritation', 1275),
#  ('Culture urine', 1275),
#  ('Impaired driving ability', 1272),
#  ('Hemiparesis', 1271),
#  ('Injection site irritation', 1267),
#  ('Computerised tomogram thorax', 1266),
#  ('Acute kidney injury', 1266),
#  ('Angiogram', 1264),
#  ('Skin disorder', 1262),
#  ('Echocardiogram abnormal', 1260),
#  ('Antibody test negative', 1251),
#  ('Skin tightness', 1244),
#  ('COVID-19 pneumonia', 1244),
#  ('Salivary hypersecretion', 1238),
#  ('Blood creatinine normal', 1223),
#  ('Incorrect product formulation administered', 1219),
#  ('Drug administered at inappropriate site', 1215),
#  ('Rheumatoid arthritis', 1211),
#  ('CSF test abnormal', 1203),
#  ('Enema administration', 1192),
#  ('Oxygen saturation', 1191),
#  ('Fibrin D dimer', 1188),
#  ('Deafness unilateral', 1179),
#  ('Parosmia', 1177),
#  ('Pollakiuria', 1175),
#  ('Muscle rigidity', 1173),
#  ('Encephalopathy', 1168),
#  ('Sensitive skin', 1168),
#  ('Neuropathy', 1163),
#  ('Vomiting projectile', 1160),
#  ('Papule', 1158),
#  ('SARS-CoV-2 antibody test', 1158),
#  ('Arrhythmia', 1154),
#  ('Listless', 1147),
#  ('Tongue disorder', 1144),
#  ('Bursitis', 1143),
#  ('Opisthotonus', 1139),
#  ('Acne', 1137),
#  ('Swelling of eyelid', 1133),
#  ('Hypophagia', 1132),
#  ('Computerised tomogram thorax abnormal', 1127),
#  ('Allergy to vaccine', 1125),
#  ('Haematocrit decreased', 1122),
#  ('Delirium', 1121),
#  ('Fibrin D dimer increased', 1119),
#  ('Product temperature excursion issue', 1119),
#  ('Weight bearing difficulty', 1116),
#  ('Lumbar puncture normal', 1112),
#  ('Visual disturbance', 1108),
#  ('Mydriasis', 1105),
#  ('Immune system disorder', 1097),
#  ('No reaction on previous exposure to drug', 1097),
#  ('Drooling', 1087),
#  ('Blood potassium normal', 1079),
#  ('Blood creatine phosphokinase increased', 1078),
#  ('Nuclear magnetic resonance imaging brain normal', 1072),
#  ('Blood creatinine increased', 1071),
#  ('Magnetic resonance imaging normal', 1071),
#  ('Dry throat', 1069),
#  ('Sluggishness', 1065),
#  ('Eye discharge', 1061),
#  ('Vaccination site mass', 1061),
#  ('Blood sodium normal', 1060),
#  ('Injection site infection', 1057),
#  ('Exposure to SARS-CoV-2', 1054),
#  ('Off label use', 1047),
#  ('Toothache', 1046),
#  ('Neurological symptom', 1034),
#  ('Purpura', 1028),
#  ('Nuchal rigidity', 1028),
#  ('White blood cell count', 1022),
#  ('Sensory loss', 1017),
#  ('Autopsy', 1016),
#  ('Grip strength decreased', 1013),
#  ('Thinking abnormal', 1008),
#  ('Dysuria', 1008),
#  ('Dermatitis', 1001),
#  ('Vasodilation procedure', 999),
#  ('Bedridden', 991),
#  ('Acoustic stimulation tests', 982),
#  ('Cardiac monitoring', 981),
#  ('Mental impairment', 969),
#  ('Urine analysis abnormal', 968),
#  ('Blood urea normal', 968),
#  ('Mouth ulceration', 965),
#  ('Injection site hypoaesthesia', 963),
#  ('Mental retardation severity unspecified', 960),
#  ('Ultrasound abdomen', 955),
#  ('Troponin normal', 955),
#  ('Antinuclear antibody', 953),
#  ('CSF culture negative', 951),
#  ('Abdominal X-ray', 951),
#  ('Aggression', 947),
#  ('Oral intake reduced', 945),
#  ('Arthropathy', 941),
#  ('Cardiac stress test', 941),
#  ('Generalised tonic-clonic seizure', 938),
#  ('Pregnancy test positive', 935),
#  ('Serum sickness', 934),
#  ('Drug toxicity', 934),
#  ('Difficulty in walking', 933),
#  ('Hypoventilation', 932),
#  ('Ultrasound abdomen abnormal', 932),
#  ('Blood glucose decreased', 929),
#  ('Gastroenteritis', 927),
#  ('Antinuclear antibody negative', 927),
#  ('Blood urine present', 923),
#  ('Magnetic resonance imaging head abnormal', 922),
#  ('Pharyngeal paraesthesia', 921),
#  ('Mucous stools', 920),
#  ('Blood chloride normal', 911),
#  ('CSF protein increased', 907),
#  ('Injection site papule', 907),
#  ('Pulmonary oedema', 905),
#  ('Respiratory failure', 903),
#  ('Laryngospasm', 902),
#  ('Middle insomnia', 902),
#  ('Dyspnoea exertional', 900),
#  ('Injection site paraesthesia', 900),
#  ('Ultrasound Doppler abnormal', 899),
#  ('Biopsy', 898),
#  ('Dizziness postural', 898),
#  ('Mouth swelling', 898),
#  ('Intermenstrual bleeding', 896),
#  ('Oral pain', 893),
#  ('Hyperacusis', 892),
#  ('Body temperature decreased', 888),
#  ('Mechanical ventilation', 888),
#  ('Flank pain', 886),
#  ('Ear disorder', 876),
#  ('Shock', 875),
#  ('Electromyogram', 872),
#  ('Magnetic resonance imaging head normal', 870),
#  ('Respiratory syncytial virus test negative', 865),
#  ('Computerised tomogram abdomen', 861),
#  ('Autoimmune disorder', 859),
#  ('Menstruation delayed', 857),
#  ('Streptococcus test', 854),
#  ('Walking aid user', 852),
#  ('Axillary mass', 848),
#  ('Spinal pain', 844),
#  ('Computerised tomogram head abnormal', 843),
#  ('Feeling jittery', 842),
#  ('Culture', 842),
#  ('Postictal state', 841),
#  ('Choking', 838),
#  ('Painful respiration', 831),
#  ('Platelet count increased', 827),
#  ('Weight increased', 824),
#  ('Diarrhoea haemorrhagic', 817),
#  ('Blood potassium decreased', 815),
#  ('Periarthritis', 815),
#  ('Oral discomfort', 815),
#  ('Cardiac disorder', 812),
#  ('Fear', 811),
#  ('Influenza B virus test', 811),
#  ('X-ray limb', 807),
#  ('Occult blood positive', 807),
#  ('Decreased eye contact', 803),
#  ('Acute respiratory failure', 803),
#  ('Full blood count abnormal', 801),
#  ('VIIth nerve paralysis', 800),
#  ('Cardiac flutter', 798),
#  ('Abdominal pain lower', 797),
#  ('Blood sodium decreased', 790),
#  ('Viral test negative', 786),
#  ('Acute myocardial infarction', 784),
#  ('Nerve injury', 781),
#  ('Facial paresis', 780),
#  ('Nuclear magnetic resonance imaging brain', 780),
#  ('Sensation of heaviness', 779),
#  ('Ocular discomfort', 779),
#  ('Scan with contrast', 779),
#  ('Neurodevelopmental disorder', 778),
#  ('Differential white blood cell count normal', 778),
#  ('Rotavirus test positive', 777),
#  ('Hypopnoea', 776),
#  ('Blood calcium normal', 774),
#  ('Personality disorder', 767),
#  ('Varicella virus test positive', 766),
#  ('Blood thyroid stimulating hormone normal', 761),
#  ('Diabetes mellitus', 760),
#  ('Pregnancy test', 760),
#  ('Nuclear magnetic resonance imaging brain abnormal', 756),
#  ('Influenza A virus test negative', 755),
#  ('Wrong technique in product usage process', 755),
#  ('Magnetic resonance imaging abnormal', 755),
#  ('Myelitis transverse', 749),
#  ('Blood urea increased', 748),
#  ('Gastrointestinal haemorrhage', 748),
#  ('Blepharospasm', 747),
#  ('Red blood cell count normal', 747),
#  ('X-ray abnormal', 747),
#  ('Secretion discharge', 747),
#  ('Hyperglycaemia', 745),
#  ('Chromaturia', 745),
#  ('Pleural effusion', 744),
#  ('Hepatitis B antibody negative', 744),
#  ('Food allergy', 742),
#  ('Glossodynia', 740),
#  ('Injection site streaking', 738),
#  ('Tonic clonic movements', 735),
#  ('Post herpetic neuralgia', 735),
#  ('Paranasal sinus discomfort', 735),
#  ('Vasculitis', 732),
#  ('Tachypnoea', 732),
#  ('Tongue oedema', 730),
#  ('Abnormal faeces', 729),
#  ('Developmental delay', 729),
#  ('Angina pectoris', 724),
#  ('Tendonitis', 724),
#  ('Periorbital swelling', 724),
#  ('Troponin I increased', 723),
#  ('Ataxia', 719),
#  ('Eating disorder', 719),
#  ('Blood alkaline phosphatase increased', 716),
#  ('Mean cell volume normal', 715),
#  ('Skin swelling', 713),
#  ('Hypothermia', 712),
#  ('Autism spectrum disorder', 711),
#  ('Leukopenia', 709),
#  ('Fibromyalgia', 708),
#  ('Overdose', 707),
#  ('Alanine aminotransferase normal', 706),
#  ('Electrocardiogram ST segment elevation', 705),
#  ('Antibody test', 705),
#  ('Culture negative', 704),
#  ('Electromyogram abnormal', 702),
#  ('Ventricular extrasystoles', 699),
#  ('Pulmonary congestion', 695),
#  ('Musculoskeletal disorder', 695),
#  ('Haematuria', 693),
#  ('Dry eye', 693),
#  ('Platelet count', 693),
#  ('Speech disorder developmental', 692),
#  ('Renal pain', 691),
#  ('Neurological examination', 690),
#  ('Similar reaction on previous exposure to drug', 688),
#  ('Red blood cell count decreased', 687),
#  ('Blood creatine phosphokinase normal', 685),
#  ('Multiple sclerosis', 683),
#  ('Carbon dioxide normal', 682),
#  ('Neurological examination normal', 680),
#  ('Haematoma', 674),
#  ('Allergy test', 673),
#  ('Wrong technique in drug usage process', 673),
#  ('Muscle contractions involuntary', 672),
#  ('Altered state of consciousness', 671),
#  ('Respiration abnormal', 668),
#  ('Neutrophil count increased', 665),
#  ('Groin pain', 664),
#  ('X-ray limb normal', 664),
#  ('Jaundice', 661),
#  ('Drug hypersensitivity', 660),
#  ('Rotator cuff syndrome', 660),
#  ('Aspartate aminotransferase normal', 660),
#  ('Culture stool negative', 660),
#  ('Neutrophil percentage increased', 660),
#  ('Pertussis', 660),
#  ('Hepatic function abnormal', 658),
#  ('Muscle fatigue', 657),
#  ('Tic', 654),
#  ('Transient ischaemic attack', 654),
#  ('Decreased immune responsiveness', 654),
#  ('Product quality issue', 652),
#  ('Hyponatraemia', 651),
#  ('Liver function test normal', 651),
#  ('Abnormal dreams', 649),
#  ('Suspected COVID-19', 647),
#  ('Borrelia test negative', 644),
#  ('Investigation', 642),
#  ('Blood alkaline phosphatase normal', 639),
#  ('Oral pruritus', 638),
#  ('Parotitis', 636),
#  ('Rheumatoid factor negative', 634),
#  ('Adverse drug reaction', 633),
#  ('Amenorrhoea', 632),
#  ('Face injury', 631),
#  ('Influenza virus test', 628),
#  ('Antinuclear antibody positive', 626),
#  ('Lymphadenitis', 621),
#  ('Blood electrolytes normal', 621),
#  ('Cardiac failure congestive', 620),
#  ('Biopsy skin abnormal', 619),
#  ('Ear swelling', 616),
#  ('Smear cervix abnormal', 615),
#  ('Angioneurotic oedema', 611),
#  ('Red cell distribution width normal', 609),
#  ('Eyelid ptosis', 606),
#  ('Blood creatine phosphokinase', 606),
#  ('General physical health deterioration', 605),
#  ('Electrocardiogram ambulatory', 603),
#  ('Lung opacity', 603),
#  ('Decreased activity', 602),
#  ('Caesarean section', 600),
#  ('Breast swelling', 599),
#  ('Psychomotor hyperactivity', 598),
#  ('Nightmare', 598),
#  ('Laryngitis', 597),
#  ('Aphonia', 596),
#  ('Product administration error', 595),
#  ('Appendicitis', 594),
#  ('Renal failure', 590),
#  ('Systemic lupus erythematosus', 590),
#  ('Depressed mood', 590),
#  ('Biopsy skin', 590),
#  ('Dermatitis contact', 589),
#  ('Respiratory viral panel', 589),
#  ('Blood bilirubin normal', 587),
#  ('Barium enema', 585),
#  ('Lymphocyte percentage decreased', 584),
#  ('Pericardial effusion', 583),
#  ('Tension', 583),
#  ('Mean cell haemoglobin concentration normal', 582),
#  ('Oral mucosal blistering', 580),
#  ('Lumbar puncture abnormal', 578),
#  ('Staphylococcal infection', 578),
#  ('Blood bilirubin increased', 577),
#  ('Epilepsy', 576),
#  ('Hepatic enzyme increased', 576),
#  ('Brain oedema', 575),
#  ('CSF test normal', 575),
#  ('Frequent bowel movements', 575),
#  ('Blood pressure', 574),
#  ('Skin striae', 571),
#  ('Protein total normal', 569),
#  ('Prothrombin time', 567),
#  ('Computerised tomogram abdomen abnormal', 566),
#  ('Blood lactic acid', 565),
#  ('Immunisation', 565),
#  ('Cerebral haemorrhage', 564),
#  ('Sinus headache', 564),
#  ('Photosensitivity reaction', 563),
#  ('Tunnel vision', 563),
#  ('Thrombocytopenic purpura', 562),
#  ('Myoclonus', 562),
#  ('Herpes simplex', 561),
#  ('Vaccination site bruising', 561),
#  ('Viral test', 560),
#  ('CSF glucose normal', 560),
#  ('Fluid retention', 559),
#  ('Drug administration error', 559),
#  ('Troponin I', 557),
#  ('Myositis', 556),
#  ('Livedo reticularis', 555),
#  ('Therapeutic response unexpected', 555),
#  ('Angiogram pulmonary abnormal', 555),
#  ('Injection site joint pain', 552),
#  ('Scar', 551),
#  ('Bacterial test negative', 547),
#  ('Sinus disorder', 547),
#  ('Skin laceration', 547),
#  ('Vitreous floaters', 546),
#  ('Tongue discomfort', 546),
#  ('Haemoptysis', 545),
#  ('Ophthalmic herpes zoster', 545),
#  ('Culture stool', 544),
#  ('Appendicectomy', 544),
#  ('Strabismus', 543),
#  ('Atelectasis', 542),
#  ('Limb injury', 542),
#  ('Stridor', 541),
#  ('Hepatitis', 539),
#  ('Breath holding', 539),
#  ('High-pitched crying', 539),
#  ('Anger', 539),
#  ('Motor dysfunction', 536),
#  ('Injection site movement impairment', 535),
#  ('Optic neuritis', 534),
#  ('Eye oedema', 532),
#  ('Ophthalmological examination', 532),
#  ('Catheterisation cardiac', 532),
#  ('Immunology test', 528),
#  ('Heart rate normal', 527),
#  ('Sinus tachycardia', 526),
#  ('Psoriasis', 525),
#  ('Infantile spitting up', 525),
#  ('International normalised ratio', 525),
#  ('Amblyopia', 524),
#  ('Blood albumin normal', 522),
#  ('Blood magnesium normal', 522),
#  ('Moaning', 521),
#  ('Haematemesis', 519),
#  ('Bronchiolitis', 519),
#  ('Mean cell haemoglobin normal', 519),
#  ('Vaccine breakthrough infection', 518),
#  ('Scratch', 516),
#  ('Injection site discharge', 516),
#  ('Monoplegia', 515),
#  ('Monocyte count increased', 514),
#  ('Scan brain', 514),
#  ('Pharyngeal hypoaesthesia', 514),
#  ('Electric shock sensation', 514),
#  ('Accidental overdose', 513),
#  ('Physical examination', 512),
#  ('Incoherent', 511),
#  ('Lymphocyte count normal', 511),
#  ('Tongue pruritus', 510),
#  ('Liver function test', 509),
#  ('Liver function test abnormal', 509),
#  ('Muscle atrophy', 508),
#  ('Social avoidant behaviour', 507),
#  ('Limb mass', 506),
#  ('Stress', 505),
#  ('Mumps', 505),
#  ('Fibrin D dimer normal', 504),
#  ('Blindness unilateral', 504),
#  ('Foaming at mouth', 503),
#  ('Upper-airway cough syndrome', 503),
#  ('Pregnancy test negative', 502),
#  ('Measles antibody negative', 501),
#  ('Ultrasound abdomen normal', 499),
#  ('Hypoglycaemia', 497),
#  ('Blood immunoglobulin G', 495),
#  ('Pulse abnormal', 494),
#  ('Weight', 493),
#  ('Needle issue', 493),
#  ('Foetal exposure during pregnancy', 493),
#  ('Formication', 492),
#  ('Therapy non-responder', 492),
#  ('Skin mass', 491),
#  ('Nerve conduction studies', 490),
#  ('Pelvic pain', 488),
#  ('Hemiplegia', 488),
#  ('Monocyte percentage', 488),
#  ('Activated partial thromboplastin time', 488),
#  ('Product use issue', 487),
#  ('Eructation', 486),
#  ('Pulse absent', 486),
#  ('Grunting', 484),
#  ('Cold compress therapy', 482),
#  ('Pulmonary thrombosis', 481),
#  ('Foetal disorder', 480),
#  ('Lacrimal disorder', 479),
#  ('Hypoaesthesia facial', 479),
#  ('Infantile spasms', 478),
#  ('Injection site pustule', 478),
#  ('Influenza A virus test positive', 478),
#  ('Blood lactate dehydrogenase increased', 477),
#  ('Streptococcal identification test negative', 477),
#  ('Mononucleosis heterophile test negative', 477),
#  ('Cardiomegaly', 476),
#  ('No therapeutic response', 476),
#  ('Polymerase chain reaction positive', 476),
#  ('Cardiac failure', 475),
#  ('Cheilitis', 475),
#  ('Anaphylactoid reaction', 473),
#  ('Blood magnesium', 473),
#  ('Thyroid function test normal', 472),
#  ('Increased upper airway secretion', 472),
#  ('Rheumatoid factor', 471),
#  ('Lymphocyte percentage', 471),
#  ('Blood pressure fluctuation', 471),
#  ('Monocyte percentage increased', 471),
#  ('Urinary retention', 470),
#  ('Colonoscopy', 470),
#  ('Mood altered', 470),
#  ('Cardio-respiratory arrest', 470),
#  ('Lung infiltration', 470),
#  ('Accidental exposure to product', 470),
#  ('Exposure via skin contact', 470),
#  ('Blood pressure abnormal', 468),
#  ('Gastrointestinal pain', 467),
#  ('Oxygen saturation normal', 467),
#  ('Extensive swelling of vaccinated limb', 467),
#  ('Transfusion', 466),
#  ('Papilloma viral infection', 466),
#  ('Asymptomatic COVID-19', 466),
#  ('Thyroid function test', 464),
#  ('Shoulder pain', 464),
#  ('Circumstance or information capable of leading to medication error', 464),
#  ('Syncope vasovagal', 462),
#  ('Polymenorrhoea', 462),
#  ('Blood immunoglobulin M', 459),
#  ('Pharyngeal erythema', 459),
#  ('Ultrasound Doppler normal', 459),
#  ('Gout', 458),
#  ('Supraventricular tachycardia', 457),
#  ('Stomach discomfort', 457),
#  ('Pulmonary pain', 457),
#  ('Contraindication to vaccination', 455),
#  ('Neutrophil count decreased', 450),
#  ('Oligomenorrhoea', 450),
#  ('Rectal haemorrhage', 449),
#  ('Breast tenderness', 449),
#  ('Hyporeflexia', 448),
#  ('Acoustic stimulation tests abnormal', 448),
#  ('Urine output decreased', 446),
#  ('Chronic obstructive pulmonary disease', 445),
#  ('Injection site scab', 445),
#  ('HIV test negative', 441),
#  ('Dermatitis allergic', 440),
#  ('Glycosylated haemoglobin', 440),
#  ('Injection site anaesthesia', 439),
#  ('Mumps antibody test negative', 438),
#  ('SARS-CoV-2 antibody test negative', 438),
#  ('Odynophagia', 437),
#  ('Vaccination error', 437),
#  ('Incontinence', 436),
#  ('Cardiovascular disorder', 435),
#  ('Breath sounds abnormal', 435),
#  ('Feeling drunk', 434),
#  ('Fungal infection', 433),
#  ('CSF white blood cell count increased', 432),
#  ('Influenza serology negative', 432),
#  ('Viral rash', 431),
#  ('Photopsia', 430),
#  ('Haemoglobin', 430),
#  ('Anaphylactic shock', 429),
#  ('Upper respiratory tract congestion', 429),
#  ('Streptococcus test positive', 429),
#  ('Magnetic resonance imaging heart', 429),
#  ('Deafness neurosensory', 428),
#  ('Lip blister', 428),
#  ('Blood albumin decreased', 426),
#  ('Emotional disorder', 426),
#  ('Ejection fraction decreased', 426),
#  ('Brain natriuretic peptide increased', 424),
#  ('Visual field defect', 423),
#  ('Blood cholesterol increased', 423),
#  ('Stool analysis', 423),
#  ('Eosinophil percentage', 423),
#  ('Sciatica', 422),
#  ('Demyelination', 420),
#  ('International normalised ratio normal', 420),
#  ('Endoscopy', 419),
#  ('Carbon dioxide decreased', 417),
#  ('Dysphemia', 416),
#  ...]

# %%
all_side_effect_list = []

# 모든 백신 부작용 추출
for i in range(len(all_rank_list)):
    if all_rank_list[i][1] >= 10:
        all_side_effect_list.append(all_rank_list[i][0])

# %%
f = open('./dataset/all_side_effect_list.txt', 'w')
f.write('\n'.join(all_side_effect_list))
f.close()

# %% [markdown]
# # 모든 백신 부작용 ∩ 코로나 백신 부작용c

# %%
except_covid_side_effect_no_rank_list = list(set(all_side_effect_list) - set(covid_side_effect_list))

# %%
except_covid_rank_list = []

for i in range(len(all_rank_list)):
    if all_rank_list[i][0] in except_covid_side_effect_no_rank_list:
        except_covid_rank_list.append(all_rank_list[i])

# %%
except_covid_rank_list
# Out:
# [('Incorrect product storage', 30416),
#  ('Convulsion', 25598),
#  ('Inappropriate schedule of drug administration', 11500),
#  ('Rash generalised', 10455),
#  ('Wrong drug administered', 9834),
#  ('Anorexia', 8246),
#  ('Incorrect storage of drug', 7195),
#  ('Drug administered to patient of inappropriate age', 6175),
#  ('Local swelling', 5485),
#  ('Expired drug administered', 4752),
#  ('Intussusception', 4160),
#  ('Nuclear magnetic resonance imaging', 3412),
#  ('Varicella post vaccine', 3347),
#  ('Activities of daily living impaired', 3341),
#  ('Sudden infant death syndrome', 3099),
#  ('Autism', 3051),
#  ('Drug exposure during pregnancy', 3041),
#  ('Skin nodule', 2516),
#  ('Pharyngolaryngeal pain', 2361),
#  ('Pruritus generalised', 2317),
#  ('Incorrect route of drug administration', 2259),
#  ('Grand mal convulsion', 2173),
#  ('Abasia', 2113),
#  ('Nuclear magnetic resonance imaging normal', 1897),
#  ('Myasthenic syndrome', 1707),
#  ('Facial palsy', 1700),
#  ('Nuclear magnetic resonance imaging abnormal', 1305),
#  ('Drug administered at inappropriate site', 1215),
#  ('Enema administration', 1192),
#  ('Neuropathy', 1163),
#  ('Opisthotonus', 1139),
#  ('Visual disturbance', 1108),
#  ('Nuclear magnetic resonance imaging brain normal', 1072),
#  ('Vasodilation procedure', 999),
#  ('Mental retardation severity unspecified', 960),
#  ('Oral intake reduced', 945),
#  ('Drug toxicity', 934),
#  ('Difficulty in walking', 933),
#  ('Hypoventilation', 932),
#  ('Decreased eye contact', 803),
#  ('VIIth nerve paralysis', 800),
#  ('Nuclear magnetic resonance imaging brain', 780),
#  ('Sensation of heaviness', 779),
#  ('Neurodevelopmental disorder', 778),
#  ('Rotavirus test positive', 777),
#  ('Personality disorder', 767),
#  ('Nuclear magnetic resonance imaging brain abnormal', 756),
#  ('Hepatitis B antibody negative', 744),
#  ('Developmental delay', 729),
#  ('Autism spectrum disorder', 711),
#  ('Wrong technique in drug usage process', 673),
#  ('Pertussis', 660),
#  ('Smear cervix abnormal', 615),
#  ('Angioneurotic oedema', 611),
#  ('Barium enema', 585),
#  ('Blood pressure', 574),
#  ('Drug administration error', 559),
#  ('Breath holding', 539),
#  ('High-pitched crying', 539),
#  ('Infantile spitting up', 525),
#  ('Social avoidant behaviour', 507),
#  ('Mumps', 505),
#  ('Measles antibody negative', 501),
#  ('Cold compress therapy', 482),
#  ('Lacrimal disorder', 479),
#  ('Hypoaesthesia facial', 479),
#  ('Infantile spasms', 478),
#  ('Streptococcal identification test negative', 477),
#  ('No therapeutic response', 476),
#  ('Papilloma viral infection', 466),
#  ('Shoulder pain', 464),
#  ('Syncope vasovagal', 462),
#  ('Stomach discomfort', 457),
#  ('Injection site anaesthesia', 439),
#  ('Mumps antibody test negative', 438),
#  ('Influenza serology negative', 432),
#  ('Antisocial behaviour', 408),
#  ('Human papilloma virus test positive', 407),
#  ('Idiopathic thrombocytopenic purpura', 399),
#  ('No adverse effect', 397),
#  ('Dermatitis diaper', 396),
#  ('Incorrect drug dosage form administered', 396),
#  ('Fontanelle bulging', 395),
#  ('Rotavirus infection', 395),
#  ("Kawasaki's disease", 389),
#  ('Generalised erythema', 384),
#  ('Rubella antibody negative', 377),
#  ('Accidental exposure', 361),
#  ('Injection site atrophy', 353),
#  ('Secondary transmission', 353),
#  ('Regressive behaviour', 353),
#  ('Hepatitis B surface antibody negative', 344),
#  ('No adverse reaction', 337),
#  ('Croup infectious', 330),
#  ('Unintended pregnancy', 321),
#  ('Head banging', 313),
#  ('Herpes simplex serology negative', 312),
#  ('Barium double contrast', 310),
#  ('Excoriation', 309),
#  ('Hearing impaired', 304),
#  ('Abortion', 300),
#  ('Laceration', 297),
#  ('Eye rolling', 295),
#  ('Dermatitis exfoliative', 294),
#  ('Blood product transfusion', 280),
#  ('Childhood disintegrative disorder', 277),
#  ('Hyperkinesia', 274),
#  ('Urine human chorionic gonadotropin positive', 271),
#  ('Rotavirus test negative', 271),
#  ('Immune thrombocytopenic purpura', 266),
#  ('Cerebellar ataxia', 264),
#  ('Congenital anomaly', 263),
#  ('Red blood cells CSF positive', 259),
#  ('Thrombocythaemia', 257),
#  ('Streptococcal identification test', 257),
#  ('Faecal incontinence', 249),
#  ('Hypotonic-hyporesponsive episode', 248),
#  ('Roseola', 240),
#  ('Auricular swelling', 239),
#  ('Oxygen supplementation', 239),
#  ('Oral administration complication', 233),
#  ('Apgar score normal', 230),
#  ('Infection transmission via personal contact', 223),
#  ('Nuclear magnetic resonance imaging spinal', 223),
#  ('Gastroenteritis rotavirus', 222),
#  ('Nuclear magnetic resonance imaging spinal abnormal', 217),
#  ('Alpha 1 foetoprotein normal', 211),
#  ('Upper extremity mass', 209),
#  ('Feeding disorder of infancy or early childhood', 205),
#  ('Measles post vaccine', 200),
#  ('Attention deficit/hyperactivity disorder', 199),
#  ('Otitis media acute', 198),
#  ('Cervical dysplasia', 197),
#  ('Measles antibody positive', 196),
#  ('Culture stool positive', 194),
#  ('Milk allergy', 192),
#  ('Post-tussive vomiting', 191),
#  ('Bordetella test positive', 188),
#  ('Metal poisoning', 186),
#  ('Blood amylase increased', 181),
#  ('Anogenital warts', 178),
#  ('Disturbance in social behaviour', 172),
#  ('Influenza serology positive', 171),
#  ('Necrosis', 168),
#  ('Candidiasis', 166),
#  ('Rubella antibody positive', 165),
#  ('Cow pox', 163),
#  ('Borrelia burgdorferi serology negative', 162),
#  ('Nuclear magnetic resonance imaging spinal normal', 162),
#  ('Injection site necrosis', 157),
#  ('Hepatitis B surface antigen positive', 156),
#  ('Mucous membrane disorder', 155),
#  ('Stereotypy', 155),
#  ('Neonatal disorder', 154),
#  ('Therapeutic response decreased', 152),
#  ('Product supply issue', 152),
#  ('Developmental regression', 151),
#  ('Cytogenetic analysis normal', 150),
#  ('Aphagia', 150),
#  ('Teething', 149),
#  ('Skin necrosis', 146),
#  ('Aphthous stomatitis', 144),
#  ('Hypochromic anaemia', 143),
#  ('Poor feeding infant', 143),
#  ('Subcutaneous nodule', 142),
#  ('Feeding disorder neonatal', 140),
#  ('Sensation of pressure', 138),
#  ('Rotavirus test', 138),
#  ('Growth retardation', 136),
#  ('Measles antibody', 135),
#  ('Barium enema abnormal', 134),
#  ('Social problem', 134),
#  ('Mumps antibody test positive', 131),
#  ('Influenza serology', 131),
#  ('Blood human chorionic gonadotropin positive', 129),
#  ('Culture wound negative', 129),
#  ('Pericardial disease', 129),
#  ('Virus serology test', 124),
#  ('Oedema genital', 122),
#  ('Seroconversion test negative', 119),
#  ('Weight gain poor', 118),
#  ('Renal failure acute', 113),
#  ('Borrelia burgdorferi serology', 113),
#  ('Intra-uterine death', 113),
#  ('Immunoglobulins increased', 112),
#  ('Post vaccination autoinoculation', 112),
#  ('Meningitis pneumococcal', 112),
#  ('Administration site swelling', 112),
#  ('Poliomyelitis', 111),
#  ('Pulse pressure decreased', 111),
#  ('Intubation', 110),
#  ('Exposure via eye contact', 110),
#  ('Product reconstitution issue', 109),
#  ('Streptococcal identification test positive', 107),
#  ('Toe walking', 107),
#  ('Nuclear magnetic resonance imaging spinal cord abnormal', 106),
#  ('Hostility', 105),
#  ('Meningism', 105),
#  ('Scrotal oedema', 104),
#  ('Hypercholesterolaemia', 104),
#  ('Varicella zoster virus serology positive', 104),
#  ('Cardiac enzymes normal', 103),
#  ('Hepatitis A', 102),
#  ('Gastrointestinal necrosis', 100),
#  ('Hand-foot-and-mouth disease', 100),
#  ('Myopericarditis', 100),
#  ('Rubella', 100),
#  ('Mumps antibody test', 99),
#  ('Hepatocellular damage', 98),
#  ('Stool analysis abnormal', 98),
#  ('Paralysis flaccid', 97),
#  ('Inability to crawl', 97),
#  ('Blood immunoglobulin M decreased', 96),
#  ('Respiratory alkalosis', 95),
#  ('Gianotti-Crosti syndrome', 95),
#  ('Tympanic membrane hyperaemia', 94),
#  ('Exaggerated startle response', 94),
#  ('Enzyme abnormality', 93),
#  ('Post vaccination syndrome', 93),
#  ('Varicella zoster serology negative', 93),
#  ('Lobar pneumonia', 93),
#  ('Immunology test abnormal', 93),
#  ('Virus culture', 92),
#  ('Herpes zoster ophthalmic', 92),
#  ('Rubella antibody test', 92),
#  ('CSF culture positive', 90),
#  ('Erythema induratum', 89),
#  ('Blood lead', 89),
#  ('Hepatitis B', 88),
#  ('Depersonalisation', 87),
#  ('Arthritis bacterial', 87),
#  ('Ear tube insertion', 87),
#  ('Drug withdrawal syndrome', 85),
#  ('Hepatitis B surface antibody positive', 85),
#  ('Exposure to vaccinated person', 84),
#  ('Morbillivirus test positive', 84),
#  ('Low birth weight baby', 84),
#  ('Learning disability', 83),
#  ('Hepatitis B antibody', 83),
#  ('Viral DNA test positive', 83),
#  ('Band neutrophil percentage', 82),
#  ('Injection site abscess sterile', 81),
#  ('Exposure via direct contact', 81),
#  ('Product packaging confusion', 81),
#  ('Complex partial seizures', 80),
#  ('Pneumonia pneumococcal', 79),
#  ('X-ray gastrointestinal tract normal', 78),
#  ('Pharmaceutical product complaint', 78),
#  ('CSF lymphocyte count normal', 78),
#  ('Joint crepitation', 78),
#  ('Asterixis', 78),
#  ('Postnasal drip', 77),
#  ('Hypertrophy', 76),
#  ('Viral titre decreased', 76),
#  ('Familial risk factor', 75),
#  ('Band neutrophil count increased', 75),
#  ('Neisseria test positive', 75),
#  ('Pneumococcal infection', 74),
#  ('Eye irrigation', 74),
#  ('Product distribution issue', 73),
#  ('Gene mutation identification test positive', 72),
#  ('Myoclonic epilepsy', 72),
#  ('Serology negative', 72),
#  ('Sensory processing disorder', 72),
#  ('Multi-organ failure', 71),
#  ('Grimacing', 71),
#  ('Biopsy muscle abnormal', 70),
#  ('Colposcopy', 70),
#  ('Coronary artery dilatation', 70),
#  ('Immunoglobulins decreased', 69),
#  ('Malabsorption', 69),
#  ('Keloid scar', 69),
#  ('Intestinal operation', 69),
#  ('Product complaint', 69),
#  ('Chromosome analysis normal', 68),
#  ('Haemophilus infection', 68),
#  ('Foreign travel', 67),
#  ('Product dose omission', 67),
#  ('Adenovirus test positive', 66),
#  ('Syphilis test negative', 65),
#  ('Sensory integrative dysfunction', 65),
#  ('Radioallergosorbent test negative', 65),
#  ('Blood heavy metal test', 65),
#  ('Injection site exfoliation', 64),
#  ('Injection site erosion', 64),
#  ('Premature menopause', 63),
#  ('Sleep study abnormal', 63),
#  ('Hepatitis A antibody positive', 63),
#  ('Radioallergosorbent test', 63),
#  ('X-ray gastrointestinal tract abnormal', 63),
#  ('Purulence', 63),
#  ('Heat rash', 62),
#  ('Medical device complication', 62),
#  ('Fine motor delay', 62),
#  ('Blood lead normal', 62),
#  ('Blood amylase', 62),
#  ('Pneumococcal bacteraemia', 62),
#  ('Band neutrophil percentage increased', 62),
#  ('Enterovirus test positive', 62),
#  ('Liquid product physical issue', 62),
#  ('Congenital central nervous system anomaly', 61),
#  ('Vascular anomaly', 61),
#  ("Cow's milk intolerance", 61),
#  ('Meningitis bacterial', 61),
#  ('Meningitis meningococcal', 61),
#  ('Drug dose omission', 61),
#  ('Monocytosis', 60),
#  ('Blood immunoglobulin E normal', 60),
#  ('CD4 lymphocytes decreased', 60),
#  ('Amino acid level', 59),
#  ('Culture throat positive', 59),
#  ('Wrong patient received medication', 59),
#  ('Injection site dermatitis', 58),
#  ('Protrusion tongue', 58),
#  ('Enterocolitis', 57),
#  ('Gross motor delay', 57),
#  ('Conjunctivitis infective', 57),
#  ('Blood immunoglobulin A decreased', 57),
#  ('Cytogenetic analysis abnormal', 57),
#  ('Heart disease congenital', 56),
#  ('Pupillary disorder', 56),
#  ('Infection parasitic', 56),
#  ('Leukoencephalomyelitis', 56),
#  ('CSF cell count increased', 56),
#  ('Hyperplasia', 55),
#  ('Vaccinia virus infection', 55),
#  ('Myofascitis', 55),
#  ('Herpes simplex serology', 55),
#  ('Product name confusion', 55),
#  ('Product use in unapproved indication', 55),
#  ('H3N2 influenza', 55),
#  ('Cerebrovascular disorder', 54),
#  ('Albuminuria', 54),
#  ('Hepatitis B antibody positive', 54),
#  ('Aspiration bone marrow', 54),
#  ('Phonophobia', 54),
#  ('Viral skin infection', 54),
#  ('Urine bilirubin decreased', 54),
#  ('Nephritis', 53),
#  ('Blood aluminium increased', 53),
#  ('CSF neutrophil count increased', 53),
#  ('Hepatitis B antigen positive', 53),
#  ('Bordetella test', 53),
#  ('Infertility female', 52),
#  ('Virus culture negative', 52),
#  ('Allergy to animal', 52),
#  ('Herpes zoster disseminated', 52),
#  ('Cervix carcinoma', 52),
#  ('Drug exposure before pregnancy', 51),
#  ('Cardiac enzymes increased', 51),
#  ('Motor developmental delay', 51),
#  ('Eschar', 51),
#  ('Bacterial culture negative', 51),
#  ('Enterovirus infection', 51),
#  ('Palpable purpura', 51),
#  ('Large for dates baby', 51),
#  ('Lung infection', 51),
#  ('Herpes simplex serology positive', 50),
#  ('Bone marrow oedema', 50),
#  ('Seborrhoeic dermatitis', 49),
#  ('Occupational therapy', 49),
#  ('Sleep study normal', 49),
#  ('Clostridium difficile toxin test', 49),
#  ('Band neutrophil count', 49),
#  ('T-lymphocyte count decreased', 49),
#  ('HIV test positive', 48),
#  ('Hepatitis C virus', 48),
#  ('Amino acid level normal', 48),
#  ('Bone scan normal', 48),
#  ('DNA test for fragile X', 48),
#  ('Encephalitis viral', 48),
#  ('Intercostal retraction', 48),
#  ('HLA marker study', 48),
#  ('Meningococcal infection', 48),
#  ('Cerebellar syndrome', 47),
#  ('Hyperchloraemia', 47),
#  ('Erysipelas', 47),
#  ('Laparotomy', 47),
#  ('Cataplexy', 47),
#  ('Bed sharing', 47),
#  ('Administration site warmth', 47),
#  ('Fasciitis', 46),
#  ('Myelopathy', 46),
#  ('CSF protein decreased', 46),
#  ('Cardiac enzymes', 46),
#  ('Pneumonia streptococcal', 46),
#  ('Urine human chorionic gonadotropin negative', 46),
#  ('Laparoscopy', 46),
#  ('Erythema infectiosum', 46),
#  ('Polycystic ovaries', 46),
#  ('Joint hyperextension', 46),
#  ('Tuberculin test positive', 45),
#  ('Poor sucking reflex', 45),
#  ('Anti-HBs antibody negative', 45),
#  ('Viral pharyngitis', 45),
#  ('Learning disorder', 45),
#  ('Haemophilus test positive', 45),
#  ('Rubber sensitivity', 45),
#  ('Infantile apnoea', 45),
#  ('Optic atrophy', 44),
#  ('Ketosis', 44),
#  ('Small for dates baby', 44),
#  ('Juvenile idiopathic arthritis', 44),
#  ('Vaccinia', 44),
#  ('Expressive language disorder', 44),
#  ('Mixed receptive-expressive language disorder', 44),
#  ('CSF monocyte count decreased', 44),
#  ('Barium enema normal', 44),
#  ('CSF pressure increased', 44),
#  ('Lymphocytic infiltration', 44),
#  ('Administration site rash', 44),
#  ('Selective eating disorder', 44),
#  ('Septic screen', 44),
#  ('Abnormal labour', 43),
#  ('Extensor plantar response', 43),
#  ('Tympanic membrane disorder', 43),
#  ('Anal fissure', 43),
#  ('Bursa injury', 43),
#  ('Blood amylase normal', 43),
#  ('Fundoscopy abnormal', 43),
#  ('Exposure during breast feeding', 43),
#  ('Escherichia test negative', 43),
#  ('Chiropractic', 43),
#  ('Hypoproteinaemia', 42),
#  ('Visual acuity tests abnormal', 42),
#  ('Chlamydial infection', 42),
#  ('Shoulder operation', 42),
#  ('Skeletal injury', 42),
#  ('Abscess sterile', 42),
#  ('Hepatitis B virus test positive', 42),
#  ('Labelled drug-drug interaction medication error', 42),
#  ('Ultrasound skull', 42),
#  ('Hepatic necrosis', 41),
#  ('Hepatosplenomegaly', 41),
#  ('Pyloric stenosis', 41),
#  ('Self injurious behaviour', 41),
#  ('Impulsive behaviour', 41),
#  ('Blood immunoglobulin A increased', 41),
#  ('Polyhydramnios', 41),
#  ('Autoimmune thrombocytopenia', 41),
#  ('Eye burns', 41),
#  ('Pertussis identification test positive', 41),
#  ('Jaw fracture', 41),
#  ('Amniotic cavity infection', 41),
#  ('Injection site eczema', 41),
#  ('Generalised vaccinia', 41),
#  ('Apparent death', 41),
#  ('CSF red blood cell count', 41),
#  ('Pleural disorder', 40),
#  ('HIV infection', 40),
#  ('Streptococcal bacteraemia', 40),
#  ('Leukocytoclastic vasculitis', 40),
#  ('Complement factor C3 decreased', 40),
#  ('Loop electrosurgical excision procedure', 40),
#  ('Educational problem', 40),
#  ('Coxsackie viral infection', 40),
#  ('Soft tissue infection', 40),
#  ('Placenta praevia', 40),
#  ('Ultrasound skull normal', 40),
#  ('Decreased vibratory sense', 40),
#  ('Nuclear magnetic resonance imaging thoracic', 40),
#  ('Arteritis', 39),
#  ('Cachexia', 39),
#  ('Borrelia burgdorferi serology positive', 39),
#  ('Neurogenic bladder', 39),
#  ('Ketoacidosis', 39),
#  ('Echolalia', 39),
#  ('Juvenile arthritis', 39),
#  ('Quadriparesis', 39),
#  ('Bacterial culture', 39),
#  ('Alpha 1 foetoprotein', 39),
#  ('Enterovirus serology test negative', 39),
#  ('Detoxification', 39),
#  ('Breech presentation', 39),
#  ('Reflex test normal', 39),
#  ('Stem cell transplant', 39),
#  ('Neurological decompensation', 39),
#  ('Biopsy site unspecified abnormal', 39),
#  ('Clostridial infection', 38),
#  ('Serology normal', 38),
#  ('Soft tissue disorder', 38),
#  ('Skin hypopigmentation', 38),
#  ('Adenovirus infection', 38),
#  ('Salmonellosis', 38),
#  ('Parasite stool test', 38),
#  ('Throat lesion', 38),
#  ('Red blood cell morphology normal', 38),
#  ('Soft tissue inflammation', 38),
#  ('Encephalitis post immunisation', 38),
#  ('Analgesic drug level therapeutic', 38),
#  ('Allergy to metals', 38),
#  ('Immunohistochemistry', 38),
#  ('Dyspraxia', 38),
#  ('Infantile back arching', 38),
#  ('Prostatic disorder', 37),
#  ('Aldolase normal', 37),
#  ('Faecal volume increased', 37),
#  ('Blood heavy metal increased', 37),
#  ('Pseudomonas infection', 37),
#  ('Molluscum contagiosum', 37),
#  ('White blood cells stool negative', 37),
#  ('Mastoiditis', 37),
#  ('Robust take following exposure to vaccinia virus', 37),
#  ('Therapeutic procedure', 37),
#  ('Hypersensitivity vasculitis', 37),
#  ('Coombs direct test positive', 36),
#  ('Speech rehabilitation', 36),
#  ('Jaundice neonatal', 36),
#  ('Autoantibody positive', 36),
#  ('CSF glucose', 36),
#  ('Bursa disorder', 36),
#  ('Intestinal functional disorder', 36),
#  ('Poor quality drug administered', 36),
#  ('Nodule on extremity', 36),
#  ('Frustration', 36),
#  ('Tonsillectomy', 36),
#  ('X-ray gastrointestinal tract', 36),
#  ('Vaccination site pustule', 36),
#  ('Drug dispensed to wrong patient', 36),
#  ('Pathological fracture', 35),
#  ('Skin cancer', 35),
#  ('Hyperexplexia', 35),
#  ('Haemolytic uraemic syndrome', 35),
#  ("Asperger's disorder", 35),
#  ('CSF immunoglobulin increased', 35),
#  ('Pneumococcal sepsis', 35),
#  ('Blood homocysteine normal', 35),
#  ('Scleral discolouration', 35),
#  ('Combined immunodeficiency', 35),
#  ('Encephalomyelitis', 35),
#  ('Anti-GAD antibody positive', 35),
#  ('Staphylococcus test', 35),
#  ('Infant irritability', 35),
#  ('Acute lymphocytic leukaemia', 34),
#  ('Ventriculo-peritoneal shunt', 34),
#  ('CD4 lymphocytes', 34),
#  ('Dysplasia', 34),
#  ('Colostomy', 34),
#  ('Head lag', 34),
#  ('Antibiotic resistant Staphylococcus test negative', 34),
#  ('Intestinal dilatation', 34),
#  ('Natural killer cell count', 34),
#  ('Paediatric autoimmune neuropsychiatric disorders associated with streptococcal infection',
#   34),
#  ('Adrenal insufficiency', 33),
#  ('Extrapyramidal disorder', 33),
#  ('Chromosome abnormality', 33),
#  ('Polymyositis', 33),
#  ('Epiglottitis', 33),
#  ('Scarlet fever', 33),
#  ('Aldolase increased', 33),
#  ('Urinary system x-ray normal', 33),
#  ('Arnold-Chiari malformation', 33),
#  ('Respiratory syncytial virus bronchiolitis', 33),
#  ('Penile swelling', 33),
#  ('Muscle oedema', 33),
#  ('Pseudo lymphoma', 32),
#  ('Myopia', 32),
#  ('Cataract operation', 32),
#  ('Barium swallow normal', 32),
#  ('Amniocentesis normal', 32),
#  ('Complement factor decreased', 32),
#  ('Anticonvulsant drug level therapeutic', 32),
#  ('Irritability postvaccinal', 32),
#  ('Partial splenic embolisation', 32),
#  ('Neurosis', 31),
#  ('Application site reaction', 31),
#  ('HLA marker study positive', 31),
#  ('Latex allergy', 31),
#  ('White blood cells stool positive', 31),
#  ('Vaginitis bacterial', 31),
#  ('Obstruction', 31),
#  ('Fluctuance', 31),
#  ('Administration site reaction', 31),
#  ('Bronchial wall thickening', 31),
#  ('Capillary nail refill test', 31),
#  ('Simplex virus test positive', 31),
#  ('Parvovirus B19 test positive', 31),
#  ('Product packaging issue', 31),
#  ('Rubulavirus test positive', 31),
#  ('CSF white blood cell differential', 31),
#  ('Anti-aquaporin-4 antibody negative', 31),
#  ('Central nervous system neoplasm', 30),
#  ('Endocrine disorder', 30),
#  ('Anorectal disorder', 30),
#  ('Benign intracranial hypertension', 30),
#  ('Dyslexia', 30),
#  ('Infantile apnoeic attack', 30),
#  ('Colposcopy abnormal', 30),
#  ('Biopsy lung abnormal', 30),
#  ('Oligohydramnios', 30),
#  ('Gastrointestinal surgery', 30),
#  ('Granulocyte count decreased', 30),
#  ('Fat necrosis', 30),
#  ('Ileostomy', 30),
#  ('Radioallergosorbent test positive', 30),
#  ('Endoscopy gastrointestinal', 30),
#  ('Oesophageal varices haemorrhage', 30),
#  ('Bursal fluid accumulation', 30),
#  ('Blood cytokine test', 30),
#  ('Salmonella test negative', 30),
#  ('Peptic ulcer', 29),
#  ('Liver tenderness', 29),
#  ('Tooth discolouration', 29),
#  ('Mononucleosis syndrome', 29),
#  ('Abscess bacterial', 29),
#  ('Toxic epidermal necrolysis', 29),
#  ("Hodgkin's disease", 29),
#  ('CSF lymphocyte count abnormal', 29),
#  ('Blood human chorionic gonadotropin', 29),
#  ('Staphylococcal skin infection', 29),
#  ('Hepatitis B antibody abnormal', 29),
#  ('Labour complication', 29),
#  ("Behcet's syndrome", 29),
#  ('Parainfluenzae virus infection', 29),
#  ('Axonal neuropathy', 29),
#  ("Non-Hodgkin's lymphoma", 29),
#  ('Histology abnormal', 29),
#  ('Parasitic test', 29),
#  ('Small intestinal intussusception reduction', 29),
#  ('Anti-ganglioside antibody negative', 29),
#  ('Human chorionic gonadotropin increased', 29),
#  ('Leukoplakia oral', 28),
#  ('Hypochloraemia', 28),
#  ('Akathisia', 28),
#  ('Urinary hesitation', 28),
#  ('Application site oedema', 28),
#  ('Microcephaly', 28),
#  ('Pica', 28),
#  ('Skin candida', 28),
#  ('Prolonged labour', 28),
#  ('Underweight', 28),
#  ('Morphoea', 28),
#  ('Basal cell carcinoma', 28),
#  ('Spirometry normal', 28),
#  ('Lumbar spinal stenosis', 28),
#  ('Vitello-intestinal duct remnant', 28),
#  ('Aspiration bone marrow abnormal', 28),
#  ('Urticaria papular', 28),
#  ('Mycobacterium test', 28),
#  ('Viral titre increased', 28),
#  ('Tryptase increased', 28),
#  ('Organic acid analysis', 28),
#  ('Nuclear magnetic resonance imaging heart', 28),
#  ('Product prescribing error', 28),
#  ('Apgar score low', 28),
#  ('Collagen disorder', 27),
#  ('Epidermal necrosis', 27),
#  ('Calcinosis', 27),
#  ('Temporal arteritis', 27),
#  ('Rash scarlatiniform', 27),
#  ('Abdominal operation', 27),
#  ('Drug dispensing error', 27),
#  ('Necrotising retinitis', 27),
#  ('Chromosomal analysis', 27),
#  ('Pneumonia primary atypical', 27),
#  ('Palmar-plantar erythrodysaesthesia syndrome', 27),
#  ('Necrotising fasciitis', 27),
#  ('Ileectomy', 27),
#  ('Intestinal anastomosis', 27),
#  ('Band neutrophil count decreased', 27),
#  ('Compartment syndrome', 27),
#  ('Parenteral nutrition', 27),
#  ('Oppositional defiant disorder', 27),
#  ('Fundoscopy normal', 27),
#  ('Smear site unspecified normal', 27),
#  ('Tubulointerstitial nephritis', 27),
#  ('B-lymphocyte count', 27),
#  ('Marrow hyperplasia', 26),
#  ('Retinitis', 26),
#  ('Deafness permanent', 26),
#  ('Blood human chorionic gonadotropin negative', 26),
#  ('Anaemia haemolytic autoimmune', 26),
#  ('Foetal distress syndrome', 26),
#  ('Neonatal respiratory distress syndrome', 26),
#  ('Retinopathy', 26),
#  ('Complement factor C3 increased', 26),
#  ('Idiopathic urticaria', 26),
#  ('CSF monocyte count increased', 26),
#  ('Perivascular dermatitis', 26),
#  ('Myofascial pain syndrome', 26),
#  ('CD8 lymphocytes', 26),
#  ('Blood copper normal', 26),
#  ('Pregnancy induced hypertension', 26),
#  ("Sandifer's syndrome", 26),
#  ('Pityriasis', 26),
#  ('Nasal flaring', 26),
#  ('Winged scapula', 26),
#  ('Fear of needles', 26),
#  ('Brachial plexus injury', 26),
#  ('Bone scan abnormal', 26),
#  ('Anticonvulsant drug level', 26),
#  ('Labour induction', 26),
#  ('Oral pustule', 26),
#  ('H1N1 influenza', 26),
#  ('Electrocardiogram PR interval', 26),
#  ('Biopsy soft tissue', 26),
#  ('Nuclear magnetic resonance imaging thoracic normal', 26),
#  ('Typhus rickettsia test', 26),
#  ('Enterococcus test positive', 26),
#  ('Optic nerve injury', 26),
#  ('Rubivirus test positive', 26),
#  ('Hepatitis B core antibody positive', 26),
#  ('Documented hypersensitivity to administered product', 26),
#  ('Duodenitis', 25),
#  ('Superinfection', 25),
#  ('Patent ductus arteriosus', 25),
#  ('Panniculitis', 25),
#  ('Tracheitis', 25),
#  ('CSF oligoclonal band', 25),
#  ('Peripheral sensorimotor neuropathy', 25),
#  ('Mycoplasma serology positive', 25),
#  ('Blood mercury', 25),
#  ('Mycoplasma serology', 25),
#  ('Cardiopulmonary failure', 25),
#  ('Biopsy cervix abnormal', 25),
#  ('Lupus-like syndrome', 25),
#  ('Skull X-ray normal', 25),
#  ('Normal newborn', 25),
#  ('Orthopoxvirus test positive', 25),
#  ('Biopsy artery normal', 25),
#  ('Base excess decreased', 25),
#  ('Injection site joint effusion', 25),
#  ('Disseminated varicella zoster vaccine virus infection', 25),
#  ('Bone marrow depression', 24),
#  ('Polyarteritis nodosa', 24),
#  ('Choreoathetosis', 24),
#  ('Congenital musculoskeletal anomaly', 24),
#  ('Hirsutism', 24),
#  ('Anoxia', 24),
#  ('Status asthmaticus', 24),
#  ('DNA antibody', 24),
#  ('Clonic convulsion', 24),
#  ('Paraparesis', 24),
#  ('Encephalomalacia', 24),
#  ('Gallbladder operation', 24),
#  ('Arthritis infective', 24),
#  ('Viral DNA test negative', 24),
#  ('Albumin CSF increased', 24),
#  ('Gamma-glutamyltransferase normal', 24),
#  ('Reticulocyte count normal', 24),
#  ('Oral fungal infection', 24),
#  ('Infection via vaccinee', 24),
#  ('Biopsy brain abnormal', 24),
#  ('Endocrine test', 24),
#  ('Mucosal discolouration', 24),
#  ('Intraocular pressure test normal', 24),
#  ('Salmonella test positive', 24),
#  ('CSF immunoglobulin G index', 24),
#  ('Nuclear magnetic resonance imaging spinal cord normal', 24),
#  ('Mycobacterium tuberculosis complex test positive', 24),
#  ('Ophthalmic herpes simplex', 24),
#  ('Varicella zoster pneumonia', 24),
#  ('West Nile virus test', 24),
#  ('Anti-aquaporin-4 antibody positive', 24),
#  ('Dairy intolerance', 24),
#  ('Arteriogram abnormal', 24),
#  ('Recalled product administered', 24),
#  ('Fibrosis tendinous', 23),
#  ('Rehabilitation therapy', 23),
#  ('Ventricular septal defect', 23),
#  ('Rash follicular', 23),
#  ('Neuroblastoma', 23),
#  ('Tympanometry normal', 23),
#  ('Bronchoscopy normal', 23),
#  ('CSF white blood cell count positive', 23),
#  ('X-ray with contrast lower gastrointestinal tract', 23),
#  ('Blood lead increased', 23),
#  ('Intestinal malrotation', 23),
#  ('Blood mercury abnormal', 23),
#  ('Dyslipidaemia', 23),
#  ('Viraemia', 23),
#  ('Rotator cuff repair', 23),
#  ('Angiotensin converting enzyme increased', 23),
#  ('Optic neuropathy', 23),
#  ('Cryotherapy', 23),
#  ('Apgar score abnormal', 23),
#  ('Neuropsychological test', 23),
#  ('Peak expiratory flow rate decreased', 23),
#  ('Arrested labour', 23),
#  ('Mitochondrial cytopathy', 23),
#  ('Face and mouth X-ray abnormal', 23),
#  ('Spondylolisthesis', 23),
#  ('Strawberry tongue', 23),
#  ('Allergic colitis', 23),
#  ('Clavicle fracture', 23),
#  ('Skeletal survey normal', 23),
#  ('Blood alcohol', 23),
#  ('Contraindicated product administered', 23),
#  ('Osteonecrosis', 22),
#  ('Febrile infection', 22),
#  ('Scotoma', 22),
#  ('Asocial behaviour', 22),
#  ('Collapse of lung', 22),
#  ('Tetanus', 22),
#  ('Corneal oedema', 22),
#  ('Prostatic specific antigen normal', 22),
#  ('Immunoelectrophoresis', 22),
#  ('Dacryostenosis acquired', 22),
#  ('Bone marrow failure', 22),
#  ('Face and mouth X-ray normal', 22),
#  ('Urine bilirubin increased', 22),
#  ('Hypermetropia', 22),
#  ('Hair metal test abnormal', 22),
#  ('Parvovirus B19 serology negative', 22),
#  ('Liver transplant', 22),
#  ('Abnormal weight gain', 22),
#  ('Gliosis', 22),
#  ('Red cell distribution width decreased', 22),
#  ('Ovarian failure', 22),
#  ('Postictal paralysis', 22),
#  ('Slit-lamp examination', 22),
#  ('Rash maculovesicular', 22),
#  ('Meningitis haemophilus', 22),
#  ('Respiratory tract infection viral', 22),
#  ('Albumin urine present', 22),
#  ('Exercise electrocardiogram normal', 22),
#  ('Exploratory operation', 22),
#  ('Hypoperfusion', 22),
#  ('Vaccination site eschar', 22),
#  ('Spinal cord oedema', 22),
#  ('Endotracheal intubation complication', 22),
#  ('White blood cells urine', 22),
#  ('Hepatitis A virus test positive', 22),
#  ('Blood pyruvic acid', 22),
#  ('Inadequate aseptic technique in use of product', 22),
#  ('Retinogram', 22),
#  ('Anti-neutrophil cytoplasmic antibody positive vasculitis', 22),
#  ('Stress fracture', 22),
#  ('Pulmonary arterial hypertension', 22),
#  ('Cervix disorder', 21),
#  ('Coagulation time prolonged', 21),
#  ('Multiple chemical sensitivity', 21),
#  ('Alcohol poisoning', 21),
#  ('Corneal disorder', 21),
#  ('Congenital brain damage', 21),
#  ('Mutism', 21),
#  ('Band neutrophil percentage decreased', 21),
#  ('Hair metal test', 21),
#  ('Barium swallow abnormal', 21),
#  ('Blood creatine decreased', 21),
#  ('Syphilis test', 21),
#  ('Vital capacity', 21),
#  ('Biopsy site unspecified normal', 21),
#  ('Erythema annulare', 21),
#  ('Serology positive', 21),
#  ('Human herpes virus 6 serology', 21),
#  ('Foetal heart rate decreased', 21),
#  ('Cerebral ventricle dilatation', 21),
#  ("Addison's disease", 21),
#  ('Oculorespiratory syndrome', 21),
#  ('Cartilage injury', 21),
#  ('Adenotonsillectomy', 21),
#  ('Cryoglobulins absent', 21),
#  ('Mononeuropathy', 21),
#  ('Painful defaecation', 21),
#  ('Autoantibody negative', 21),
#  ('Drug level', 21),
#  ('Oedema mucosal', 21),
#  ('Gastrointestinal viral infection', 21),
#  ('Aspiration joint normal', 21),
#  ('Fear of falling', 21),
#  ('Cytology normal', 21),
#  ('Vaccination site abscess', 21),
#  ('T-lymphocyte count normal', 21),
#  ('Anti-NMDA antibody negative', 21),
#  ('Emotional poverty', 21),
#  ('Escherichia test', 21),
#  ('Cytopenia', 21),
#  ('Corneal lesion', 20),
#  ('Malignant melanoma', 20),
#  ('Prothrombin level increased', 20),
#  ('Drug level increased', 20),
#  ('Ovarian disorder', 20),
#  ('Lymphoid tissue hyperplasia', 20),
#  ('Astigmatism', 20),
#  ('Histrionic personality disorder', 20),
#  ('Milia', 20),
#  ('Evans syndrome', 20),
#  ('Bone marrow transplant', 20),
#  ('Pelvic inflammatory disease', 20),
#  ('Mycoplasma infection', 20),
#  ('Hypogammaglobulinaemia', 20),
#  ('Toxoplasma serology', 20),
#  ('Arachnoid cyst', 20),
#  ('Trendelenburg position', 20),
#  ('Bacteria stool identified', 20),
#  ('Refusal of treatment by relative', 20),
#  ('Urine protein, quantitative', 20),
#  ('Urine human chorionic gonadotropin', 20),
#  ('Blood zinc', 20),
#  ('Diabetes mellitus insulin-dependent', 20),
#  ('Biopsy brain', 20),
#  ('Herpangina', 20),
#  ('Fungal test positive', 20),
#  ('Arthroscopy', 20),
#  ('Allergy to plants', 20),
#  ('Helicobacter pylori identification test negative', 20),
#  ('Hepatitis B core antigen', 20),
#  ('Apnoea test', 20),
#  ('Reaction to food additive', 20),
#  ('Platelet morphology normal', 20),
#  ('Atonic seizures', 20),
#  ('Oral mucosal discolouration', 20),
#  ('Diabetic neuropathy', 20),
#  ('Immunodeficiency common variable', 20),
#  ('Cranial nerve paralysis', 20),
#  ('Blood parathyroid hormone normal', 20),
#  ('Laryngoscopy abnormal', 20),
#  ('Nasal ulcer', 20),
#  ('Campylobacter test positive', 20),
#  ('Product label issue', 20),
#  ('Adenoidal hypertrophy', 20),
#  ('Seroma', 20),
#  ('Injection site joint inflammation', 20),
#  ('Bandaemia', 20),
#  ('CD4 lymphocytes normal', 20),
#  ('CD8 lymphocytes decreased', 20),
#  ('Subchorionic haemorrhage', 20),
#  ('Hereditary neuropathy with liability to pressure palsies', 20),
#  ('Vaginal candidiasis', 19),
#  ('Balanitis', 19),
#  ('Injection site fibrosis', 19),
#  ('Oesophageal ulcer', 19),
#  ('Visual evoked potentials', 19),
#  ('Neonatal apnoeic attack', 19),
#  ('Cutaneous lupus erythematosus', 19),
#  ('Paronychia', 19),
#  ('Gastrostomy tube insertion', 19),
#  ('Sweat test normal', 19),
#  ('Hypermobility syndrome', 19),
#  ('Urine mercury abnormal', 19),
#  ('Sensitivity of teeth', 19),
#  ('Transient acantholytic dermatosis', 19),
#  ('Rectal prolapse', 19),
#  ('Lipoatrophy', 19),
#  ('Brain stem auditory evoked response normal', 19),
#  ('Blood human chorionic gonadotropin increased', 19),
#  ('Mycotic allergy', 19),
#  ('Necrotising colitis', 19),
#  ('Neuromyelitis optica', 19),
#  ('Alopecia universalis', 19),
#  ('Soft tissue injury', 19),
#  ('Ear injury', 19),
#  ('Performance status decreased', 19),
#  ('Genital haemorrhage', 19),
#  ('Biopsy cervix', 19),
#  ('Blindness cortical', 19),
#  ('Rash rubelliform', 19),
#  ('Platelet morphology abnormal', 19),
#  ('Fontanelle depressed', 19),
#  ('Death neonatal', 19),
#  ('Beta globulin normal', 19),
#  ('Bronchoalveolar lavage abnormal', 19),
#  ('Nuclear magnetic resonance imaging thoracic abnormal', 19),
#  ('Electrocardiogram ST segment normal', 19),
#  ('Trichotillomania', 19),
#  ('Cell marker', 19),
#  ('Hepatitis B DNA assay negative', 19),
#  ('Wound complication', 19),
#  ('Toxicologic test abnormal', 19),
#  ('CSF immunoglobulin', 19),
#  ('Limb deformity', 19),
#  ('Red blood cell morphology abnormal', 19),
#  ('Large intestinal obstruction reduction', 19),
#  ('B-lymphocyte count decreased', 19),
#  ('Product contamination physical', 19),
#  ('Ketonuria', 19),
#  ('Ear infection viral', 19),
#  ('X-ray with contrast', 19),
#  ('Injection site granuloma', 19),
#  ('HLA-B*27 positive', 19),
#  ('Dehydroepiandrosterone decreased', 19),
#  ('Vertical infection transmission', 19),
#  ('Cancer surgery', 19),
#  ('Product physical issue', 19),
#  ('Ehlers-Danlos syndrome', 19),
#  ('Bilirubinuria', 18),
#  ('Adrenal haemorrhage', 18),
#  ('Vitreous disorder', 18),
#  ('Muscle haemorrhage', 18),
#  ('Vascular occlusion', 18),
#  ('Alkalosis', 18),
#  ('Glycosuria', 18),
#  ('Drug dependence', 18),
#  ('Blood thromboplastin decreased', 18),
#  ('Diabetes insipidus', 18),
#  ('Tracheobronchitis', 18),
#  ('Drug level decreased', 18),
#  ('Cholestasis', 18),
#  ('Myeloid leukaemia', 18),
#  ('Sensorimotor disorder', 18),
#  ('Renal failure chronic', 18),
#  ('Brain stem auditory evoked response abnormal', 18),
#  ('Arteriovenous malformation', 18),
#  ('DNA antibody positive', 18),
#  ('Reflux oesophagitis', 18),
#  ('Cytomegalovirus antibody positive', 18),
#  ('Adjustment disorder', 18),
#  ('Glucose urine', 18),
#  ('Prophylaxis', 18),
#  ...]

# %%
except_covid_side_effect_list = []

# 코로나 백신 부작용을 제외한 목록
for i in range(len(except_covid_rank_list)):
    except_covid_side_effect_list.append(except_covid_rank_list[i][0])

# %%
f = open('./dataset/except_covid_side_effect_list.txt', 'w')
f.write('\n'.join(except_covid_side_effect_list))
f.close()

# %%
len(except_covid_rank_list)
# Out:
# 1956
